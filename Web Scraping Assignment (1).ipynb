# %%
#Importing Libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# # 1.Write a python program to display all the header tags

# %%
page=requests.get("https://en.wikipedia.org/wiki/Main_Page")
page
# Out:
# <Response [200]>

# %%
#to find all header tags

page =requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(page.content,'html.parser')
url_tags=soup.find_all(['h1','h2','h3','h4','h5','h6'])
url_tags
# Out:
# [<h1 class="firstHeading" id="firstHeading">Main Page</h1>,
#  <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
#  <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>,
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <title>
#    Book Review - One Last Stop by Casey McQuiston | BookPage
#   </title>
#   <meta content="Bursting with heart, banter and a respect for queer history and community, One Last Stop may be the best read of the summer." name="description"/>
#   <link href="https://bookpage.com/reviews/26344-casey-mcquiston-one-last-stop-romance" rel="canonical"/>
#   <meta content="BookPage.com" property="og:site_name"/>
#   <meta content="Book Review - One Last Stop by Casey McQuiston" property="og:title"/>
#   <meta content="Bursting with heart, banter and a respect for queer history and community, One Last Stop may be the best read of the summer." property="og:description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://bookpage.com/reviews/26344-casey-mcquiston-one-last-stop-romance" property="og:url"/>
# ...

# %% [markdown]
# # 2.Write a python program to display IMDB's Top rated 100 movies data

# %%
import pandas as pd

# %%
page=requests.get("https://www.imdb.com/chart/top/")
page
# Out:
# <Response [200]>

# %%
import pandas as pd
url='https://www.imdb.com/chart/top/'
response=requests.get(url)
soup=BeautifulSoup(response.text,'lxml')

movies = soup.select('td.titleColumn')
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]


imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    data = {"movie_title": movie_title,
            "year": year,
            "rating": ratings[index]}
    imdb.append(data)
dataset=pd.DataFrame(imdb)
print(dataset)
# Out:
#                                movie_title  year             rating
# 0                 The Shawshank Redemption  1994  9.219808250641313
# 1                            The Godfather  1972  9.147524786525494
# 2                   The Godfather: Part II  1974   8.97999410958424
# 3                          The Dark Knight  2008  8.970012840414007
# 4                             12 Angry Men  1957  8.935103501652215
# ..                                     ...   ...                ...
# 95                                  Jagten  2012  8.261159496370478
# 96                     Singin' in the Rain  1952  8.258113377879177
# 97                      North by Northwest  1959  8.258018005706283
# 98                            Idi i smotri  1985  8.257360109994822
# 99   Eternal Sunshine of the Spotless Mind  2004  8.256836367633332
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3.write a python program to display IMDB's Top rated 100 Indian movies data

# %%
import pandas as pd
url = 'https://www.imdb.com/india/top-rated-indian-movies/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=8a7876cd-2844-4017-846a-2c0876945b7b&pf_rd_r=YPPPTG56059W7F0P2EYZ&pf_rd_s=right-5&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_india_tr_rhs_1'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    data = {"movie_title": movie_title,
            "year": year,
            "rating": ratings[index]}
    imdb.append(data)
dataset=pd.DataFrame(imdb)
print(dataset)
# Out:
#                  movie_title  year             rating
# 0            Pather Panchali  1955  8.507353396212261
# 1                    Nayakan  1987  8.482080825715874
# 2          Pariyerum Perumal  2018  8.474181582380117
# 3                 Anbe Sivam  2003   8.47202092320688
# 4                    Golmaal  1979  8.463173868006274
# ..                       ...   ...                ...
# 95                Chhichhore  2019  8.066969583989868
# 96  Uri: The Surgical Strike  2018  8.064143346875792
# 97                 Virumandi  2004  8.063521120823015
# 98                        PK  2014   8.06251513829281
# 99                     Lucia  2013  8.054873374698966
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4.Write a python program to scrap book name,author name,genre and book review of  any 5 books.

# %%
URL = 'https://bookpage.com/reviews'
page = requests.get(URL)
page
# Out:
# <Response [200]>

# %%
URL = 'https://bookpage.com/reviews'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find("div", class_='bp-well')
i = 0
for row in data.find_all('div', class_='flex-article-content'):
    if i<=4:
        book_name = row.find('a').get_text()
        cells = row.find_all('p')
        author_name = cells[0].get_text()
        genre = cells[1].get_text()
        URL = 'https://bookpage.com/' + row.find('a').attrs['href']
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')
        reviews = soup.find('div', class_='article-body').get_text()
        print(book_name)
        print(author_name)
        print(genre)
        print(reviews)
    else:
        break
# Out:
#  ★ Walking on Cowrie Shells
#
# Nana Nkweti
#
#
# Fiction
#  /
# Short Stories
#
#
#
# A short fiction collection can be an enchanting contradiction. The assorted stories may defy easy classification as they span genres, styles and points of view, and yet they all spring from one writer’s singular voice. Cameroonian American writer Nana Nkweti commands such contradictions in her debut collection, Walking on Cowrie Shells, a cluster of 10 dazzling stories that are as diverse as they are vibrant.
# ...

# %% [markdown]
# # 5.Write a python program to scrap cricket rankings from 'www.icc-cricket.com'

# %% [markdown]
# # 1.Top 10 ODI teams in mens cricket along with the records for macthes,points and rating.

# %%
URL = 'https://www.icc-cricket.com/rankings/mens/team-rankings/odi'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find_all('table', class_='table')
i = 0
for row in data[0].find('tbody').find_all('tr'):
    if i <=9:
        cells = row.find_all("td")
        rank = cells[0].get_text()
        team = cells[1].get_text()
        matches = cells[2].get_text()
        points = cells[3].get_text()
        rating = cells[4].get_text()
        print(rank, end='\n ')
        print(team, end='\n ')
        print(matches, end=' \n')
        print(points, end=' \n')
        print(rating, end=' \n')
        i += 1
    else:
        break
# Out:
# 1
#
#
# New Zealand
# NZ
#
#  17
# 2,054
#
#                             121
#
#
#
# 2
#
#
# Australia
# AUS
#
#  25
# 2,945
# 118
# 3
#
#
# India
# IND
#
#  29
# 3,344
# 115
# 4
#
#
# England
# ENG
#
#  27
# 3,100
# 115
# 5
#
#
# South Africa
# SA
#
#  20
# 2,137
# 107
# 6
#
#
# Pakistan
# PAK
#
#  24
# 2,323
# 97
# 7
#
#
# Bangladesh
# BAN
#
#  27
# 2,438
# 90
# 8
#
#
# West Indies
# WI
#
#  27
# 2,222
# 82
# 9
#
#
# Sri Lanka
# SL
#
#  24
# 1,876
# 78
# 10
#
#
# Afghanistan
# AFG
#
#  17
# 1,054
# 62

# %% [markdown]
# # 2.Top 10 ODI Batsmen in men along with the records of thier team and rating

# %%
URL = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find("div", {"data-cricket-role": "batting"})
top_player = data.find('div', class_='rankings-block__top-player')
top_rank = top_player.find('div', class_='rankings-block__banner--pos').get_text()
top_rating = top_player.find('div', class_='rankings-block__banner--rating').get_text()
top_name = top_player.find('div', class_='rankings-block__banner--name').get_text()
top_county = top_player.find('div', class_='rankings-block__banner--nationality').get_text().split()[0]
print(top_rank, end='\n ')
print(top_rating, end='\n ')
print(top_name, end=' \n')
print(top_county, end=' \n')
i = 0
for row in data.find('tbody').find_all('tr'):
    if i <=8:
        rating = row.find('td', class_='table-body__cell u-text-right rating').get_text().strip()
        position = row.find('td', class_='table-body__cell--position').get_text().strip()
        name = row.find('td', class_='table-body__cell name').get_text().strip()
        team = row.find('span', class_='table-body__logo-text').get_text().strip()
        print(rating, end='\n ')
        print(position, end='\n ')
        print(name, end=' \n')
        print(team, end=' \n')
        i += 1
    else:
        break
# Out:
#                         1
#
#
#  865
#  Babar Azam
# PAK
# 857
#  2
#  Virat Kohli
# IND
# 825
#  3
#  Rohit Sharma
# IND
# 801
#  4
#  Ross Taylor
# NZ
# 791
#  5
#  Aaron Finch
# AUS
# 785
#  6
#  Jonny Bairstow
# ENG
# 778
#  7
#  Fakhar Zaman
# PAK
# 778
#
#  Francois du Plessis
# SA
# 773
#  9
#  David Warner
# AUS
# 773
#
#  Shai Hope
# WI

# %% [markdown]
# # 3. Top 10 ODI bowlers along with the records of thier team and rating.

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find("div", {"data-cricket-role": "bowling"})
top_player = data.find('div', class_='rankings-block__top-player')
top_rank = top_player.find('div', class_='rankings-block__banner--pos').get_text()
top_rating = top_player.find('div', class_='rankings-block__banner--rating').get_text()
top_name = top_player.find('div', class_='rankings-block__banner--name').get_text()
top_county = top_player.find('div', class_='rankings-block__banner--nationality').get_text().split()[0]
print(top_rank, end='\n ')
print(top_rating, end='\n ')
print(top_name, end=' \n')
print(top_county, end=' \n')
i = 0
for row in data.find('tbody').find_all('tr'):
    if i <=8:
        rating = row.find('td', class_='table-body__cell u-text-right rating').get_text().strip()
        position = row.find('td', class_='table-body__cell--position').get_text().strip()
        name = row.find('td', class_='table-body__cell name').get_text().strip()
        team = row.find('span', class_='table-body__logo-text').get_text().strip()
        print(rating, end='\n ')
        print(position, end='\n ')
        print(name, end=' \n')
        print(team, end=' \n')
        i += 1
    else:
        break
# Out:
#                         1
#
#
#  737
#  Trent Boult
# NZ
# 713
#  2
#  Mehedi Hasan
# BAN
# 708
#  3
#  Mujeeb Ur Rahman
# AFG
# 691
#  4
#  Matt Henry
# NZ
# 690
#  5
#  Jasprit Bumrah
# IND
# 666
#  6
#  Kagiso Rabada
# SA
# 665
#  7
#  Chris Woakes
# ENG
# 660
#  8
#  Josh Hazlewood
# AUS
# 646
#  9
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#  Pat Cummins
# AUS
# 645
#  10
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#  Mustafizur Rahman
# BAN

# %% [markdown]
# # 6.Write a python program to scrap  cricket rankings from 'www.icc-cricket.com'

# %% [markdown]
# # 1. 10 ODI teams in womens cricket along with the records for macthes,points and rating.

# %%
URL = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find_all('table', class_='table')
i = 0
for row in data[0].find('tbody').find_all('tr'):
    if i <=9:
        cells = row.find_all("td")
        rank = cells[0].get_text()
        team = cells[1].get_text()
        matches = cells[2].get_text()
        points = cells[3].get_text()
        rating = cells[4].get_text()
        print(rank, end='\n ')
        print(team, end='\n ')
        print(matches, end=' \n')
        print(points, end=' \n')
        print(rating, end=' \n')
        i += 1
    else:
        break
# Out:
# 1
#
#
# Australia
# AUS
#
#  18
# 2,955
#
#                             164
#
#
#
# 2
#
#
# South Africa
# SA
#
#  24
# 2,828
# 118
# 3
#
#
# England
# ENG
#
#  17
# 1,993
# 117
# 4
#
#
# India
# IND
#
#  20
# 2,226
# 111
# 5
#
#
# New Zealand
# NZ
#
#  21
# 1,947
# 93
# 6
#
#
# West Indies
# WI
#
#  12
# 1,025
# 85
# 7
#
#
# Pakistan
# PAK
#
#  15
# 1,101
# 73
# 8
#
#
# Bangladesh
# BAN
#
#  5
# 306
# 61
# 9
#
#
# Sri Lanka
# SL
#
#  11
# 519
# 47
# 10
#
#
# Ireland
# IRE
#
#  2
# 25
# 13

# %% [markdown]
# # 2..Top 10 womens ODI players  along with the records of thier team and rating

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find("div", {"data-cricket-role": "batting"})
top_player = data.find('div', class_='rankings-block__top-player')
top_rank = top_player.find('div', class_='rankings-block__banner--pos').get_text()
top_rating = top_player.find('div', class_='rankings-block__banner--rating').get_text()
top_name = top_player.find('div', class_='rankings-block__banner--name').get_text()
top_county = top_player.find('div', class_='rankings-block__banner--nationality').get_text().split()[0]
print(top_rank, end='\n ')
print(top_rating, end='\n ')
print(top_name, end=' \n')
print(top_county, end=' \n')
i = 0
for row in data.find('tbody').find_all('tr'):
    if i <=8:
        rating = row.find('td', class_='table-body__cell u-text-right rating').get_text().strip()
        position = row.find('td', class_='table-body__cell--position').get_text().strip()
        name = row.find('td', class_='table-body__cell name').get_text().strip()
        team = row.find('span', class_='table-body__logo-text').get_text().strip()
        print(rating, end='\n ')
        print(position, end='\n ')
        print(name, end=' \n')
        print(team, end=' \n')
        i += 1
    else:
        break
# Out:
#                         1
#
#
#  765
#  Tammy Beaumont
# ENG
# 758
#  2
#  Lizelle Lee
# SA
# 756
#  3
#  Alyssa Healy
# AUS
# 746
#  4
#  Stafanie Taylor
# WI
# 723
#  5
#  Meg Lanning
# AUS
# 715
#  6
#  Amy Satterthwaite
# NZ
# 710
#  7
#  Smriti Mandhana
# IND
# 709
#  8
#  Mithali Raj
# IND
# 685
#  9
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#  Natalie Sciver
# ENG
# 683
#  10
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#  Laura Wolvaardt
# SA

# %% [markdown]
# # 3. Top 10 womens ODI all-rounder along with the records of thier team and rating.

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find("div", {"data-cricket-role": "bowling"})
top_player = data.find('div', class_='rankings-block__top-player')
top_rank = top_player.find('div', class_='rankings-block__banner--pos').get_text()
top_rating = top_player.find('div', class_='rankings-block__banner--rating').get_text()
top_name = top_player.find('div', class_='rankings-block__banner--name').get_text()
top_county = top_player.find('div', class_='rankings-block__banner--nationality').get_text().split()[0]
print(top_rank, end='\n ')
print(top_rating, end='\n ')
print(top_name, end=' \n')
print(top_county, end=' \n')
i = 0
for row in data.find('tbody').find_all('tr'):
    if i <=8:
        rating = row.find('td', class_='table-body__cell u-text-right rating').get_text().strip()
        position = row.find('td', class_='table-body__cell--position').get_text().strip()
        name = row.find('td', class_='table-body__cell name').get_text().strip()
        team = row.find('span', class_='table-body__logo-text').get_text().strip()
        print(rating, end='\n ')
        print(position, end='\n ')
        print(name, end=' \n')
        print(team, end=' \n')
        i += 1
    else:
        break
# Out:
#                         1
#
#
#  808
#  Jess Jonassen
# AUS
# 762
#  2
#  Megan Schutt
# AUS
# 747
#  3
#  Marizanne Kapp
# SA
# 717
#  4
#  Shabnim Ismail
# SA
# 681
#  5
#  Jhulan Goswami
# IND
# 655
#  6
#  Katherine Brunt
# ENG
# 641
#  7
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#  Poonam Yadav
# IND
# 638
#  8
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#  Ayabonga Khaka
# SA
# 616
#  9
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#  Ellyse Perry
# AUS
# 610
#  10
#  Shikha Pandey
# IND

# %% [markdown]
# # 7.Write a python program to scrap details of all the mobile phones under rs.20,000 listed on Amazon.in .The scraped Data should include Product Name,Price,Image, URL and Average Rating.

# %%
URL = 'https://www.amazon.in/best-mobile-under-20000/s?k=best+mobile+under+20000'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find_all("div", {'data-component-type': 's-search-result'})
for row in data:
    prd_img = row.find('span', {'data-component-type':'s-product-image'}).find('a').attrs['href']
    prd_name = row.find('span', class_="a-size-medium a-color-base a-text-normal").get_text()
    price = row.find('span', class_='a-price').find_all('span')[0].get_text()
    rating = row.find('div', class_='a-section a-spacing-none a-spacing-top-micro').find_all('span')[0].attrs['aria-label']
    print(prd_img)
    print(prd_name)
    print(price)
    print(rating)
# Out:
# /Redmi-9A-2GB-32GB-Storage/dp/B08696XB4B?dchild=1
# Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery
# ₹6,999
# 4.2 out of 5 stars
# /Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ?dchild=1
# Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate
# ₹10,999
# 4.0 out of 5 stars
# /Redmi-Sky-Blue-64GB-Storage/dp/B08697N43N?dchild=1
# Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor
# ₹8,799
# 4.2 out of 5 stars
# /Samsung-Galaxy-Ocean-128GB-Storage/dp/B07HGGYWL6?dchild=1
# Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)
# ₹14,999
# 4.3 out of 5 stars
# /Oppo-Mystery-Storage-Additional-Exchange/dp/B08444S68L?dchild=1
# Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹11,990
# 4.2 out of 5 stars
# ...

# %% [markdown]
# # 8.Write a python program to extract information about the local weather from the National Weather Service .

# %%
URL = 'https://forecast.weather.gov/MapClick.php?lat=37.7771&lon=-122.4196&unit=0&lg=english&FcstType=text&TextType=1'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find_all("table")[1]
data = data.find("tr", {'valign': 'top'})
for row in data:
    print(row.get_text())
# Out:
# Today: Sunny, with a high near 68. Breezy, with a west southwest wind 7 to 12 mph increasing to 17 to 22 mph in the afternoon. Winds could gust as high as 29 mph.
#
# Tonight: Increasing clouds, with a low around 54. West wind 16 to 20 mph, with gusts as high as 25 mph.
#
# Friday: Mostly cloudy, then gradually becoming sunny, with a high near 68. Breezy, with a west wind 14 to 19 mph increasing to 20 to 25 mph in the afternoon. Winds could gust as high as 32 mph.
#
# Friday Night: Mostly clear, with a low around 52. Breezy, with a west wind 21 to 26 mph decreasing to 11 to 16 mph after midnight. Winds could gust as high as 34 mph.
#
# Saturday: Sunny, with a high near 68. West wind 5 to 10 mph increasing to 15 to 20 mph in the afternoon. Winds could gust as high as 25 mph.
#
# Saturday Night: Mostly clear, with a low around 52.
#
# Sunday: Sunny, with a high near 67.
#
# Sunday Night: Mostly clear, with a low around 52.
#
# Monday: Sunny, with a high near 64.
#
# ...

# %% [markdown]
# # 9.Write a python program to scrap fresher job listing

# %%
page=requests.get("https://internshala.com/fresher-jobs")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
#   <meta content="272234782795210" property="fb:app_id"/>
#   <meta content="article" property="og:type"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="@Internshala" name="twitter:site"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@internshala" name="twitter:creator"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="#ffffff" name="msapplication-navbutton-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
#First ,we will extract the html tag where we have the first job title.

first_title=soup.find('div',class_="heading_4_5 profile")
first_title
# Out:
# <div class="heading_4_5 profile">
# <a href="/fresher-job/detail/remote-backend-developer-fresher-jobs-at-homejam1622587980">Backend Developer</a> </div>

# %%
#print first job title

first_title.text
# Out:
# '\nBackend Developer '

# %%
first_title.text.replace('\n','')
# Out:
# 'Backend Developer '

# %%
#we will extract the html tage where we have the first company names.
first_company=soup.find('a',class_="link_display_like_text")
first_company
# Out:
# <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-HomeJam">
#                         HomeJam                    </a>

# %%
#print first company name
first_company.text
# Out:
# '\n                        HomeJam                    '

# %%
first_company.text.replace('\n', '')
# Out:
# '                        HomeJam                    '

# %%
# so lets extarct all the tags having the job-titles.

titles=soup.find_all('div',class_="heading_4_5 profile")
titles
# Out:
# [<div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-backend-developer-fresher-jobs-at-homejam1622587980">Backend Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/junior-operations-executive-fresher-jobs-in-bangalore-at-ncti-llp1622288356">Junior Operations Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-internal-audit-associate-fresher-jobs-at-transpeninsula-llc1622704230">Internal Audit Associate</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/business-marketing-manager-fresher-jobs-in-multiple-locations-at-mentorboxx1622665379">Business Marketing Manager</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-react-native-developer-fresher-jobs-at-runners-planet1622653252">React Native Developer</a> </div>,
#  <div class="heading_4_5 profile">
# ...

# %%
#now we will have all the tags in which there are the job titles.

#now we will extarct the text from these one by one by looping over these tags.

job_titles=[] #empty list to store the..
for i in titles:
    job_titles.append(i.text)
job_titles
# Out:
# ['\nBackend Developer ',
#  '\nJunior Operations Executive ',
#  '\nInternal Audit Associate ',
#  '\nBusiness Marketing Manager ',
#  '\nReact Native Developer ',
#  '\nResearch And Communications Associate ',
#  '\nData Scientist ',
#  '\nData Science Django Developer ',
#  '\nCorporate Sales Associate ',
#  '\nFull Stack Developer ',
#  '\nFull Stack Developer (MERN) ',
#  '\nBusiness Development Executive ',
#  '\nSales Development Representative ',
#  '\nGraphic Designer ',
#  '\nOperations Executive ',
#  '\nBusiness Development Executive ',
#  '\nAdmission Counselor (Sales) ',
#  '\nSales And Business Development Analyst ',
#  '\nGrowth Hacking Digital Marketer ',
#  '\nJunior Node.js Developer ',
#  '\nJunior Digital Marketing Executive ',
#  '\niOS App Developer ',
#  '\nFood Journalist ',
#  '\nJunior Software Developer ',
#  '\nFull Stack Developer ',
#  '\nBusiness Analyst ',
#  '\nAssociate Full Stack Developer ',
#  '\nFull Stack Engineer ',
#  '\nProduct Marketer ',
# ...

# %%
job_titles=[] #empty list to store the..
for i in titles:
    job_titles.append(i.text.replace('\n',''))
job_titles
# Out:
# ['Backend Developer ',
#  'Junior Operations Executive ',
#  'Internal Audit Associate ',
#  'Business Marketing Manager ',
#  'React Native Developer ',
#  'Research And Communications Associate ',
#  'Data Scientist ',
#  'Data Science Django Developer ',
#  'Corporate Sales Associate ',
#  'Full Stack Developer ',
#  'Full Stack Developer (MERN) ',
#  'Business Development Executive ',
#  'Sales Development Representative ',
#  'Graphic Designer ',
#  'Operations Executive ',
#  'Business Development Executive ',
#  'Admission Counselor (Sales) ',
#  'Sales And Business Development Analyst ',
#  'Growth Hacking Digital Marketer ',
#  'Junior Node.js Developer ',
#  'Junior Digital Marketing Executive ',
#  'iOS App Developer ',
#  'Food Journalist ',
#  'Junior Software Developer ',
#  'Full Stack Developer ',
#  'Business Analyst ',
#  'Associate Full Stack Developer ',
#  'Full Stack Engineer ',
#  'Product Marketer ',
#  'Business Development Executive ',
# ...
