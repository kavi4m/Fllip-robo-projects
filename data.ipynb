# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/Data file.csv')
df.head()
# Out:
#    Unnamed: 0  label       msisdn  ...  payback90  pcircle       pdate
# 0           1      0  21408I70789  ...  29.000000      UPW  2016-07-20
# 1           2      1  76462I70374  ...   0.000000      UPW  2016-08-10
# 2           3      1  17943I70372  ...   0.000000      UPW  2016-08-19
# 3           4      1  55773I70781  ...   0.000000      UPW  2016-06-06
# 4           5      1  03813I82730  ...   2.333333      UPW  2016-06-22
#
# [5 rows x 37 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0  label       msisdn  ...  payback90  pcircle       pdate
# 18701       18702      1  49420I85330  ...        5.0      UPW  2016-07-11
# 18702       18703      1  17398I90844  ...        0.0      UPW  2016-07-18
# 18703       18704      1  91791I90844  ...        2.0      UPW  2016-06-17
# 18704       18705      1  59755I85320  ...        8.0      UPW  2016-07-10
# 18705       18706      1  76433I70786  ...        NaN      NaN         NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# **original data size and shape**

# %%
df.size
# Out:
# 692122

# %%
df.shape
# Out:
# (18706, 37)

# %% [markdown]
# **Dropping values**

# %%
df_new= df.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# ### Info. on the data

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18706 entries, 0 to 18705
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   label                 18706 non-null  int64
#  1   msisdn                18706 non-null  object
#  2   aon                   18706 non-null  float64
#  3   daily_decr30          18706 non-null  float64
#  4   daily_decr90          18706 non-null  float64
#  5   rental30              18706 non-null  float64
#  6   rental90              18706 non-null  float64
#  7   last_rech_date_ma     18705 non-null  float64
#  8   last_rech_date_da     18705 non-null  float64
#  9   last_rech_amt_ma      18705 non-null  float64
#  10  cnt_ma_rech30         18705 non-null  float64
#  11  fr_ma_rech30          18705 non-null  float64
#  12  sumamnt_ma_rech30     18705 non-null  float64
#  13  medianamnt_ma_rech30  18705 non-null  float64
# ...

# %% [markdown]
# ### Statistical info.

# %%
df_new.describe()
# Out:
#               label            aon  ...     payback30     payback90
# count  18706.000000   18706.000000  ...  18705.000000  18705.000000
# mean       0.875013    8100.565307  ...      3.523427      4.330887
# std        0.330713   75175.162426  ...      9.241394     10.301643
# min        0.000000     -48.000000  ...      0.000000      0.000000
# 25%        1.000000     248.000000  ...      0.000000      0.000000
# 50%        1.000000     522.000000  ...      0.000000      1.666667
# 75%        1.000000     983.000000  ...      3.800000      4.500000
# max        1.000000  995119.092520  ...    170.000000    170.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# ### Check for null values

# %%
df_new.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       1
# last_rech_date_da       1
# last_rech_amt_ma        1
# cnt_ma_rech30           1
# fr_ma_rech30            1
# sumamnt_ma_rech30       1
# medianamnt_ma_rech30    1
# medianmarechprebal30    1
# cnt_ma_rech90           1
# fr_ma_rech90            1
# sumamnt_ma_rech90       1
# medianamnt_ma_rech90    1
# medianmarechprebal90    1
# cnt_da_rech30           1
# fr_da_rech30            1
# cnt_da_rech90           1
# fr_da_rech90            1
# cnt_loans30             1
# amnt_loans30            1
# maxamnt_loans30         1
# medianamnt_loans30      1
# cnt_loans90             1
# amnt_loans90            1
# maxamnt_loans90         1
# medianamnt_loans90      1
# payback30               1
# payback90               1
# pcircle                 1
# ...

# %%
df_new.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       1
# last_rech_date_da       1
# last_rech_amt_ma        1
# cnt_ma_rech30           1
# fr_ma_rech30            1
# sumamnt_ma_rech30       1
# medianamnt_ma_rech30    1
# medianmarechprebal30    1
# cnt_ma_rech90           1
# fr_ma_rech90            1
# sumamnt_ma_rech90       1
# medianamnt_ma_rech90    1
# medianmarechprebal90    1
# cnt_da_rech30           1
# fr_da_rech30            1
# cnt_da_rech90           1
# fr_da_rech90            1
# cnt_loans30             1
# amnt_loans30            1
# maxamnt_loans30         1
# medianamnt_loans30      1
# cnt_loans90             1
# amnt_loans90            1
# maxamnt_loans90         1
# medianamnt_loans90      1
# payback30               1
# payback90               1
# pcircle                 1
# ...

# %%
df_new.dropna(inplace=True)

# %%
df_new.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
sns.heatmap(df.isnull())

# %%
dfcor=df.corr()
dfcor
# Out:
#                          label       aon  ...  payback30  payback90
# label                 1.000000  0.003546  ...   0.036776   0.037888
# aon                   0.003546  1.000000  ...   0.007374   0.004528
# daily_decr30          0.167276  0.002160  ...   0.024752   0.042636
# daily_decr90          0.166354  0.002166  ...   0.016657   0.035447
# rental30              0.051348  0.017439  ...   0.069803   0.089962
# rental90              0.069588  0.015707  ...   0.067794   0.094891
# last_rech_date_ma     0.008687  0.002451  ...  -0.006064  -0.010426
# last_rech_date_da     0.008195 -0.006353  ...   0.006330   0.002850
# last_rech_amt_ma      0.134292  0.005414  ...  -0.021585  -0.008740
# cnt_ma_rech30         0.236240 -0.002341  ...   0.035650   0.015220
# fr_ma_rech30          0.013135  0.000500  ...   0.013768   0.013262
# sumamnt_ma_rech30     0.202048  0.007350  ...  -0.002279  -0.012128
# medianamnt_ma_rech30  0.132300  0.004602  ...  -0.012039   0.002977
# ...

# %%
sns.heatmap(dfcor)

# %%
sns.color_palatte?
# Out:
# Object `sns.color_palatte` not found.

# %%
sns.heatmap?

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18705 entries, 0 to 18704
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   label                 18705 non-null  int64
#  1   msisdn                18705 non-null  object
#  2   aon                   18705 non-null  float64
#  3   daily_decr30          18705 non-null  float64
#  4   daily_decr90          18705 non-null  float64
#  5   rental30              18705 non-null  float64
#  6   rental90              18705 non-null  float64
#  7   last_rech_date_ma     18705 non-null  float64
#  8   last_rech_date_da     18705 non-null  float64
#  9   last_rech_amt_ma      18705 non-null  float64
#  10  cnt_ma_rech30         18705 non-null  float64
#  11  fr_ma_rech30          18705 non-null  float64
#  12  sumamnt_ma_rech30     18705 non-null  float64
#  13  medianamnt_ma_rech30  18705 non-null  float64
# ...

# %% [markdown]
# ### Now our data is nan free
#
# ### Next we will remove the duplicate rows if any

# %%
duplicate_rows_df = df_new[df_new.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 36)

# %% [markdown]
# ### Dropping the duplicates

# %%
df= df_new.drop_duplicates()
df.head()
# Out:
#    label       msisdn    aon  ...  payback90  pcircle       pdate
# 0      0  21408I70789  272.0  ...  29.000000      UPW  2016-07-20
# 1      1  76462I70374  712.0  ...   0.000000      UPW  2016-08-10
# 2      1  17943I70372  535.0  ...   0.000000      UPW  2016-08-19
# 3      1  55773I70781  241.0  ...   0.000000      UPW  2016-06-06
# 4      1  03813I82730  947.0  ...   2.333333      UPW  2016-06-22
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Counting the number of rows after removing duplicates.

# %%
df.count()
# Out:
# label                   18705
# msisdn                  18705
# aon                     18705
# daily_decr30            18705
# daily_decr90            18705
# rental30                18705
# rental90                18705
# last_rech_date_ma       18705
# last_rech_date_da       18705
# last_rech_amt_ma        18705
# cnt_ma_rech30           18705
# fr_ma_rech30            18705
# sumamnt_ma_rech30       18705
# medianamnt_ma_rech30    18705
# medianmarechprebal30    18705
# cnt_ma_rech90           18705
# fr_ma_rech90            18705
# sumamnt_ma_rech90       18705
# medianamnt_ma_rech90    18705
# medianmarechprebal90    18705
# cnt_da_rech30           18705
# fr_da_rech30            18705
# cnt_da_rech90           18705
# fr_da_rech90            18705
# cnt_loans30             18705
# amnt_loans30            18705
# maxamnt_loans30         18705
# medianamnt_loans30      18705
# cnt_loans90             18705
# amnt_loans90            18705
# maxamnt_loans90         18705
# ...

# %% [markdown]
# ### Outlier detection

# %%
import seaborn as sns
sns.boxplot(x=df['label'])

# %% [markdown]
# ### Let us plot some histograms

# %%
df.head()
# Out:
#    label       msisdn    aon  ...  payback90  pcircle       pdate
# 0      0  21408I70789  272.0  ...  29.000000      UPW  2016-07-20
# 1      1  76462I70374  712.0  ...   0.000000      UPW  2016-08-10
# 2      1  17943I70372  535.0  ...   0.000000      UPW  2016-08-19
# 3      1  55773I70781  241.0  ...   0.000000      UPW  2016-06-06
# 4      1  03813I82730  947.0  ...   2.333333      UPW  2016-06-22
#
# [5 rows x 36 columns]

# %%
df.tail()
# Out:
#        label       msisdn     aon  ...  payback90  pcircle       pdate
# 55985      1  99248I70376   709.0  ...   1.500000      UPW  2016-07-24
# 55986      1  15532I90583   360.0  ...   2.777778      UPW  2016-06-25
# 55987      1  49623I89234  1924.0  ...  14.000000      UPW  2016-07-18
# 55988      0  41138I70787   311.0  ...   0.000000      UPW  2016-07-13
# 55989      1  15462I90842   692.0  ...   4.666667      UPW  2016-07-12
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55990 entries, 0 to 55989
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   label                 55990 non-null  int64
#  1   msisdn                55990 non-null  object
#  2   aon                   55990 non-null  float64
#  3   daily_decr30          55990 non-null  float64
#  4   daily_decr90          55990 non-null  float64
#  5   rental30              55990 non-null  float64
#  6   rental90              55990 non-null  float64
#  7   last_rech_date_ma     55990 non-null  float64
#  8   last_rech_date_da     55990 non-null  float64
#  9   last_rech_amt_ma      55990 non-null  int64
#  10  cnt_ma_rech30         55990 non-null  int64
#  11  fr_ma_rech30          55990 non-null  float64
#  12  sumamnt_ma_rech30     55990 non-null  int64
#  13  medianamnt_ma_rech30  55990 non-null  float64
# ...

# %%
df['cnt_loans30'].max()
# Out:
# 36.0

# %%
df['cnt_loans30'].min()
# Out:
# 0.0

# %%
df['cnt_loans30'].mean()
# Out:
# 2.7529558849794604

# %%
df.hist(column='cnt_loans30')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1425b2acd0>]],
#       dtype=object)

# %%
df.groupby('label').sum().head()
# Out:
#                 aon  daily_decr30  ...      payback30      payback90
# label                              ...
# 0      5.778651e+07  9.050523e+06  ...   16094.482892   21189.783419
# 1      4.049987e+08  2.902959e+08  ...  175981.164356  219869.417540
#
# [2 rows x 32 columns]

# %%
df.groupby('label')['last_rech_date_ma'].sum().head().plot.bar()

# %% [markdown]
# ### Let us plot a line chart to see our results

# %%
keys = [pair for pair, df in df.groupby(['aon'])]

plt.plot(keys, df.groupby(['aon']).count()['count'])
plt.xticks(keys)
plt.grid()
plt.show()

# %% [markdown]
# ### Visualizing label column using distplot

# %%
sns.distplot(df['label'])

# %% [markdown]
# ## Faceted histograms

# %%
with sns.axes_style('white'):
    g = sns.factorplot("pcircle", data=df, aspect=3,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=1)

# %% [markdown]
# ## Model Building

# %%
df2 = df
df3 = df
df.head()
# Out:
#    label       msisdn    aon  ...  payback90  pcircle       pdate
# 0      0  21408I70789  272.0  ...  29.000000      UPW  2016-07-20
# 1      1  76462I70374  712.0  ...   0.000000      UPW  2016-08-10
# 2      1  17943I70372  535.0  ...   0.000000      UPW  2016-08-19
# 3      1  55773I70781  241.0  ...   0.000000      UPW  2016-06-06
# 4      1  03813I82730  947.0  ...   2.333333      UPW  2016-06-22
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6244 entries, 0 to 6243
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   label                 6244 non-null   int64
#  1   msisdn                6244 non-null   object
#  2   aon                   6244 non-null   float64
#  3   daily_decr30          6244 non-null   float64
#  4   daily_decr90          6244 non-null   float64
#  5   rental30              6244 non-null   float64
#  6   rental90              6244 non-null   float64
#  7   last_rech_date_ma     6244 non-null   float64
#  8   last_rech_date_da     6244 non-null   float64
#  9   last_rech_amt_ma      6244 non-null   int64
#  10  cnt_ma_rech30         6244 non-null   int64
#  11  fr_ma_rech30          6244 non-null   float64
#  12  sumamnt_ma_rech30     6244 non-null   float64
#  13  medianamnt_ma_rech30  6244 non-null   float64
# ...

# %%
Y = df['label']
X = pd.get_dummies(df.drop(['label'], axis=1))

# %%
print(X)
# Out:
#          aon  daily_decr30  ...  pdate_2016-08-20  pdate_2016-08-21
# 0      272.0   3055.050000  ...                 0                 0
# 1      712.0  12122.000000  ...                 0                 0
# 2      535.0   1398.000000  ...                 0                 0
# 3      241.0     21.228000  ...                 0                 0
# 4      947.0    150.619333  ...                 0                 0
# ...      ...           ...  ...               ...               ...
# 6239  1554.0    622.150000  ...                 0                 0
# 6240  1225.0      3.593333  ...                 0                 0
# 6241  1233.0      9.100000  ...                 0                 0
# 6242   828.0     12.791667  ...                 0                 0
# 6243   206.0   7599.893667  ...                 0                 0
#
# [6244 rows x 6341 columns]

# %%
print(Y)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6239    1
# 6240    1
# 6241    1
# 6242    1
# 6243    1
# Name: label, Length: 6244, dtype: int64

# %%
from sklearn.preprocessing import PowerTransformer
X = PowerTransformer(method = 'yeo-johnson').fit_transform(X)
X

# %% [markdown]
# ### 1. Neural network classifier

# %%
from sklearn.metrics import classification_report, confusion_matrix
def classify(model, X, Y):
    # train the model
    model.fit(X_train, Y_train)
    score = model.predict(X_test)
    print(classification_report(Y_test,score))
    print(confusion_matrix(Y_test, score))

    # cross-validation
    #score = cross_val_score(model, X, Y, cv=3)
    #print("CV Score:", np.mean(score)*100)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(50,), max_iter=10, alpha=1e-4,solver='sgd', verbose=10, random_state=1,learning_rate_init=.1)

# %%
classify(clf, X, Y)
# Out:
# Iteration 1, loss = 0.37460843
# Iteration 2, loss = 0.03534533
# Iteration 3, loss = 0.00160272
# Iteration 4, loss = 0.00064122
# Iteration 5, loss = 0.00049152
# Iteration 6, loss = 0.00041754
# Iteration 7, loss = 0.00036658
# Iteration 8, loss = 0.00032847
# Iteration 9, loss = 0.00029849
# Iteration 10, loss = 0.00027399
#               precision    recall  f1-score   support
#
#            0       0.53      0.35      0.42       165
#            1       0.91      0.95      0.93      1084
#
#     accuracy                           0.87      1249
#    macro avg       0.72      0.65      0.68      1249
# weighted avg       0.86      0.87      0.86      1249
#
# [[  58  107]
#  [  52 1032]]

# %%
pred = clf.predict(X_test)
pred
# Out:
# array([1, 0, 1, ..., 1, 0, 1])

# %% [markdown]
# **Hyperparameter tuning**

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
from sklearn.model_selection import GridSearchCV

clf2 = GridSearchCV(clf, parameter_space, verbose=3, n_jobs=-1, cv=3)
clf2.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed: 10.2min finished
# Iteration 1, loss = 0.36288484
# Iteration 2, loss = 0.04467462
# Iteration 3, loss = 0.03150806
# Iteration 4, loss = 0.03096804
# Iteration 5, loss = 0.03055928
# Iteration 6, loss = 0.03017409
# Iteration 7, loss = 0.02980225
# Iteration 8, loss = 0.02944100
# Iteration 9, loss = 0.02908706
# Iteration 10, loss = 0.02874009
# GridSearchCV(cv=3, error_score=nan,
#              estimator=MLPClassifier(activation='relu', alpha=0.0001,
#                                      batch_size='auto', beta_1=0.9,
#                                      beta_2=0.999, early_stopping=False,
# ...

# %%
clf2.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.05,
#  'hidden_layer_sizes': (100,),
#  'learning_rate': 'constant',
#  'solver': 'sgd'}

# %%
clf2.best_estimator_
# Out:
# MLPClassifier(activation='relu', alpha=0.05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.1, max_fun=15000, max_iter=10, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='sgd', tol=0.0001,
#               validation_fraction=0.1, verbose=10, warm_start=False)

# %%
clf = MLPClassifier(hidden_layer_sizes=(50, 100, 50), max_iter=10, alpha=0.0001,solver='sgd', verbose=10, random_state=1,learning_rate_init=.1,learning_rate='constant')

# %%
classify(clf, X, Y)
# Out:
# Iteration 1, loss = 0.36258673
# Iteration 2, loss = 0.10285467
# Iteration 3, loss = 0.00309457
# Iteration 4, loss = 0.00039869
# Iteration 5, loss = 0.00027454
# Iteration 6, loss = 0.00022934
# Iteration 7, loss = 0.00020249
# Iteration 8, loss = 0.00018443
# Iteration 9, loss = 0.00017156
# Iteration 10, loss = 0.00016039
#               precision    recall  f1-score   support
#
#            0       0.48      0.19      0.27       165
#            1       0.89      0.97      0.93      1084
#
#     accuracy                           0.87      1249
#    macro avg       0.68      0.58      0.60      1249
# weighted avg       0.83      0.87      0.84      1249
#
# [[  31  134]
#  [  34 1050]]

# %%
grid.best_params_
grid.best_estimator_
grid_predictions = grid.predict(X_test)
print(confusion_matrix(Y_test,grid_predictions))
print(classification_report(Y_test,grid_predictions))
# Out:
# [[   0  165]
#  [   0 1084]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       165
#            1       0.87      1.00      0.93      1084
#
#     accuracy                           0.87      1249
#    macro avg       0.43      0.50      0.46      1249
# weighted avg       0.75      0.87      0.81      1249

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
conf_mat=confusion_matrix(Y_test,pred)
print(conf_mat)
# Out:
# [[   0  165]
#  [   0 1084]]

# %%
print(classification_report(Y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       165
#            1       0.87      1.00      0.93      1084
#
#     accuracy                           0.87      1249
#    macro avg       0.43      0.50      0.46      1249
# weighted avg       0.75      0.87      0.81      1249

# %%
print("Misclassification error rate:",round(np.mean(pred!=Y_test),3))
# Out:
# Misclassification error rate: 0.132

# %%
error_rate = []

# Will take some time
for i in range(1,60):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,Y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != Y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,60),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=8)
plt.title('Error Rate vs. K Value', fontsize=20)
plt.xlabel('K',fontsize=15)
plt.ylabel('Error (misclassification) Rate',fontsize=15)
# Out:
# Text(0, 0.5, 'Error (misclassification) Rate')

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
clf = KNeighborsRegressor()
scores = cross_val_score(clf, X, Y, cv=3,scoring='neg_mean_squared_error')
print("MSE:"+ str(-scores.mean()))
# Out:
# MSE:0.12395916086920328

# %%
#KNN
from sklearn.model_selection import GridSearchCV
rf_params = {
    'n_neighbors': [2, 3, 5,7,10]
}
clf = KNeighborsRegressor()
grid = GridSearchCV(clf, rf_params, cv=3, scoring='neg_mean_squared_error')
grid.fit(X, Y)
print(grid.best_params_)
print("MSE:"+ str(-grid.best_score_))
# Out:
# {'n_neighbors': 2}
# MSE:0.12395916086920328

# %% [markdown]
# **Random forest regressor**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
#Random Forest
clf = RandomForestRegressor()
scores = cross_val_score(clf, X, Y, cv=3,scoring='neg_mean_squared_error') # 3-fold cross-validation
print("MSE:"+ str(-scores.mean()))
# Out:
# MSE:0.07452517856310308

# %%
#Random Forest
from sklearn.model_selection import GridSearchCV
# Define the hyperparameter configuration space
rf_params = {
    'n_estimators': [10, 20, 30],
    #'max_features': ['sqrt',0.5],
    'max_depth': [15,20,30,50],
    #'min_samples_leaf': [1,2,4,8],
    #"bootstrap":[True,False],
    #"criterion":['mse','mae']
}
clf = RandomForestRegressor(random_state=0)
grid = GridSearchCV(clf, rf_params, cv=3, scoring='neg_mean_squared_error')
grid.fit(X, Y)
print(grid.best_params_)
print("MSE:"+ str(-grid.best_score_))
# Out:
# {'max_depth': 15, 'n_estimators': 30}
# MSE:0.07328779931393382
