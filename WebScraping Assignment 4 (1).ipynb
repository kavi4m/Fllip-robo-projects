# %% [markdown]
# 1.Scrape the details of most viewed videos on YouTube from Wikipedia:

# %%
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup
import time

# %%
if __name__ == "__main__":
    browser = webdriver.Chrome()
    browser.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")
    time.sleep(3)
    html = browser.page_source
    soup = BeautifulSoup(html,"html.parser")
    table = soup.find("table",{"class":"wikitable sortable jquery-tablesorter"})
    rows = table.find_all("tr")
    rows.pop(0)

    for row in rows:
        data = list()
        data = row.text.split("\n")
        if len(data)>3:
            data.pop(0)
            data.pop()
            data.pop()
        if len(data)==5:
            print(data)
# Out:
# ['1.', '"Baby Shark Dance"[22]', "Pinkfong Kids' Songs & Stories", '8.95', 'June 17, 2016']
# ['2.', '"Despacito"[24]', 'Luis Fonsi', '7.44', 'January 12, 2017']
# ['3.', '"Johny Johny Yes Papa"[25]', 'LooLoo Kids', '5.54', 'October 8, 2016']
# ['4.', '"Shape of You"[26]', 'Ed Sheeran', '5.38', 'January 30, 2017']
# ['5.', '"See You Again"[27]', 'Wiz Khalifa', '5.17', 'April 6, 2015']
# ['6.', '"Masha and the Bear – Recipe for Disaster"[30]', 'Get Movies', '4.44', 'January 31, 2012']
# ['7.', '"Bath Song"[31]', 'Cocomelon – Nursery Rhymes', '4.29', 'May 2, 2018']
# ['8.', '"Learning Colors – Colorful Eggs on a Farm"[32]', 'Miroshka TV', '4.25', 'February 27, 2018']
# ['9.', '"Uptown Funk"[33]', 'Mark Ronson', '4.22', 'November 19, 2014']
# ['10.', '"Gangnam Style"[34]', 'Psy', '4.11', 'July 15, 2012']
# ['11.', '"Phonics Song with Two Words"[36]', 'ChuChu TV', '3.98', 'March 6, 2014']
# ['12.', '"Sugar"[37]', 'Maroon 5', '3.50', 'January 14, 2015']
# ['13.', '"Dame Tu Cosita"[38]', 'El Chombo', '3.45', 'April 5, 2018']
# ['14.', '"Sorry"[39]', 'Justin Bieber', '3.45', 'October 22, 2015']
# ['15.', '"Roar"[40]', 'Katy Perry', '3.38', 'September 5, 2013']
# ['16.', '"Counting Stars"[41]', 'OneRepublic', '3.34', 'May 31, 2013']
# ['17.', '"Thinking Out Loud"[42]', 'Ed Sheeran', '3.29', 'October 7, 2014']
# ['18.', '"Wheels on the Bus"[43]', 'Cocomelon – Nursery Rhymes', '3.15', 'May 24, 2018']
# ['19.', '"Dark Horse"[44]', 'Katy Perry', '3.10', 'February 20, 2014']
# ['20.', '"Faded"[45]', 'Alan Walker', '3.10', 'December 3, 2015']
# ['21.', '"Shake It Off"[46]', 'Taylor Swift', '3.07', 'August 18, 2014']
# ['22.', '"Girls Like You"[47]', 'Maroon 5', '3.07', 'May 31, 2018']
# ['23.', '"Lean On"[48]', 'Major Lazer', '3.06', 'March 22, 2015']
# ['24.', '"Bailando"[49]', 'Enrique Iglesias', '3.06', 'April 11, 2014']
# ['25.', '"Let Her Go"[50]', 'Passenger', '3.02', 'July 25, 2012']
# ['26.', '"Mi Gente"[51]', 'J Balvin', '2.94', 'June 29, 2017']
# ['27.', '"Perfect"[52]', 'Ed Sheeran', '2.89', 'November 9, 2017']
# ['28.', '"Waka Waka (This Time for Africa)"[53]', 'Shakira', '2.88', 'June 4, 2010']
# ['29.', '"Axel F"[54]', 'Crazy Frog', '2.87', 'June 16, 2009']
# ['30.', '"Hello"[55]', 'Adele', '2.85', 'October 22, 2015']

# %% [markdown]
# 2.Scrape the details team India’s international fixtures from bcci.tv.

# %%
if __name__ == "__main__":
    browser = webdriver.Chrome()
    browser.get("https://www.bcci.tv/")

    #Goto Fixtures    
    browser.find_element_by_link_text("Fixtures").click()

    html = browser.page_source
    soup = BeautifulSoup(html,"html.parser")

    div = soup.find("div",{"class":"js-list"})
    anchors = div.find_all("a")

    for a in anchors:
        data = []
        try:
            match_title = soup.find("strong",{"class":"fixture__name fixture__name--with-margin"}).text
            match_series = soup.find("span",{"class":"u-unskewed-text fixture__tournament-label u-truncated"}).text
            place = soup.find("p",{"class":"fixture__additional-info"}).text
            date = soup.find("span",{"class":"fixture__date"}).text
            timing = soup.find("span",{"class":"fixture__time"}).text
            
            data.append(match_title)
            data.append(match_series)
            data.append(place)
            data.append(date)
            data.append(timing)

            print(data)
        except Exception as e:
            print(e)
            continue
# Out:
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']
# ['1st ODI', 'Sri Lanka v India 2021', '\n1st ODI\nR Premadasa Stadium, Colombo\n', '18', '15:00 IST']

# %% [markdown]
# 3.Scrape the details of selenium exception from guru99.com.

# %%
if __name__ == "__main__":
    browser = webdriver.Chrome()
    browser.get("https://www.guru99.com/")

    #Goto Selenium
    browser.find_element_by_link_text("Selenium").click()

    #Goto exception handling topic
    xpath = '//a[@title = "Selenium Exception Handling (Common Exceptions List)"]'
    browser.find_element_by_xpath(xpath).click()

    html = browser.page_source
    soup = BeautifulSoup(html,"html.parser")
    table = soup.find("table",{"class":"table table-striped"})
    rows = table.find_all("tr")

    for row in rows:
        print(row.text)
        print()
# Out:
# Exception name Description
#
# ElementNotVisibleException This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.
#
# ElementNotSelectableException This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.
#
# NoSuchElementException This Exception occurs if an element could not be found.
#
# NoSuchFrameException This Exception occurs if the frame target to be switched to does not exist.
#
# NoAlertPresentException This Exception occurs when you switch to no presented alert.
#
# NoSuchWindowException This Exception occurs if the window target to be switch does not exist.
#
# StaleElementReferenceException This Selenium exception occurs happens when the web element is detached from the current DOM.
#
# SessionNotFoundException The WebDriver is acting after you quit the browser.
#
# TimeoutException Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn't found in the specified time.
#
# WebDriverException This Exception takes place when the WebDriver is acting right after you close the browser.
#
# ConnectionClosedException This type of Exception takes place when there is a disconnection in the driver.
#
# ElementClickInterceptedException The command may not be completed as the element receiving the events is concealing the element which was requested clicked.
#
# ElementNotInteractableException This Selenium exception is thrown when any element is presented in the DOM. However, it is impossible to interact with such an element.
#
# ErrorInResponseException This happens while interacting with the Firefox extension or the remote driver server.
#
# ErrorHandler.UnknownServerException Exception is used as a placeholder in case if the server returns an error without a stack trace.
#
# ImeActivationFailedException This expectation will occur when IME engine activation has failed.
#
# ImeNotAvailableException It takes place when IME support is unavailable.
#
# InsecureCertificateException Navigation made the user agent to hit a certificate warning. This can cause by an invalid or expired TLS certificate.
#
# InvalidArgumentException It occurs when an argument does not belong to the expected type.
#
# InvalidCookieDomainException This happens when you try to add a cookie under a different domain instead of current URL.
#
# InvalidCoordinatesException This type of Exception matches an interacting operation that is not valid.
#
# InvalidElementStateExceptio It occurs when command can't be finished when the element is invalid.
#
# InvalidSessionIdException This Exception took place when the given session ID is not included in the list of active sessions. It means the session does not exist or is inactive either.
#
# InvalidSwitchToTargetException This occurs when the frame or window target to be switched does not exist.
#
# JavascriptException This issue occurs while executing JavaScript given by the user.
#
# JsonException It occurs when you afford to get the session when the session is not created.
#
# NoSuchAttributeException This kind of Exception occurs when the attribute of an element could not be found.
#
# MoveTargetOutOfBoundsException It takes place if the target provided to the ActionChains move() methodology is not valid. For Example, out of the document.
#
# NoSuchContextException ContextAware does mobile device testing.
#
# NoSuchCookieException This Exception occurs when no cookie matching with the given pathname found for all the associated cookies of the currently browsing document.
#
# NotFoundException This Exception is a subclass of WebDriverException. This will occur when an element on the DOM does not exist.
#
# RemoteDriverServerException This Selenium exception is thrown when the server is not responding because of the problem that the capabilities described are not proper.
#
# ScreenshotException It is not possible to capture a screen.
#
# SessionNotCreatedException It happens when a new session could not be successfully created.
#
# UnableToSetCookieException This occurs if a driver is unable to set a cookie.
#
# UnexpectedTagNameException Happens if a support class did not get a web element as expected.
#
# UnhandledAlertException This expectation occurs when there is an alert, but WebDriver is not able to perform Alert operation.
#
# UnexpectedAlertPresentException It occurs when there is the appearance of an unexpected alert.
#
# UnknownMethodException This Exception happens when the requested command matches with a known URL but and not matching with a methodology for a specific URL.
#
# UnreachableBrowserException This Exception occurs only when the browser is not able to be opened or crashed because of some reason.
#
# UnsupportedCommandException This occurs when remote WebDriver does n't send valid commands as expected.

# %% [markdown]
# 4.Scrape the details of State-wise GDP of India from statisticstime.com

# %%
if __name__ == "__main__":
    browser = webdriver.Chrome()
    browser.get("http://statisticstimes.com/")
    browser.get("http://statisticstimes.com/economy/india-statistics.php")

    xpath = '/html/body/div[2]/div[2]/div[2]/ul/li[1]'
    browser.find_element_by_xpath(xpath).click()

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")
    table = soup.find("table",{"id":"table_id"})
    rows = table.find_all("tr")
    rows.pop(0)
    rows.pop(0)

    for i, row in enumerate(rows, start = 1):
        try:
            row = row.text.split("\n")
            rank = i
            if(i>9):
                state = row[0][2:]
            else:
                state = row[0][1:]
            gsdp_19_20 = row[1]
            gsdp_18_19 = row[2]
            share = row[3]
            gdp = row[4]
            print(rank, state, gsdp_19_20, gsdp_18_19, share, gdp)
            print()
        except:
            continue
# Out:
# 1 Maharashtra - 2,632,792 13.94% 399.921
#
# 2 Tamil Nadu 1,845,853 1,630,208 8.63% 247.629
#
# 3 Uttar Pradesh 1,687,818 1,584,764 8.39% 240.726
#
# 4 Gujarat - 1,502,899 7.96% 228.290
#
# 5 Karnataka 1,631,977 1,493,127 7.91% 226.806
#
# 6 West Bengal 1,253,832 1,089,898 5.77% 165.556
#
# 7 Rajasthan 1,020,989 942,586 4.99% 143.179
#
# 8 Andhra Pradesh 972,782 862,957 4.57% 131.083
#
# 9 Telangana 969,604 861,031 4.56% 130.791
#
# 10 Madhya Pradesh 906,672 809,592 4.29% 122.977
#
# 11 Kerala - 781,653 4.14% 118.733
#
# 12 Delhi 856,112 774,870 4.10% 117.703
#
# 13 Haryana 831,610 734,163 3.89% 111.519
#
# 14 Bihar 611,804 530,363 2.81% 80.562
#
# 15 Punjab 574,760 526,376 2.79% 79.957
#
# 16 Odisha 521,275 487,805 2.58% 74.098
#
# 17 Assam - 315,881 1.67% 47.982
#
# 18 Chhattisgarh 329,180 304,063 1.61% 46.187
#
# 19 Jharkhand 328,598 297,204 1.57% 45.145
#
# 20 Uttarakhand - 245,895 1.30% 37.351
#
# 21 Jammu & Kashmir - 155,956 0.83% 23.690
#
# 22 Himachal Pradesh 165,472 153,845 0.81% 23.369
#
# 23 Goa 80,449 73,170 0.39% 11.115
#
# 24 Tripura 55,984 49,845 0.26% 7.571
#
# 25 Chandigarh - 42,114 0.22% 6.397
#
# 26 Puducherry 38,253 34,433 0.18% 5.230
#
# 27 Meghalaya 36,572 33,481 0.18% 5.086
#
# 28 Sikkim 32,496 28,723 0.15% 4.363
#
# 29 Manipur 31,790 27,870 0.15% 4.233
#
# 30 Nagaland - 27,283 0.14% 4.144
#
# 31 Arunachal Pradesh - 24,603 0.13% 3.737
#
# 32 Mizoram 26,503 22,287 0.12% 3.385

# %% [markdown]
# 5.Scrape the details of trending repositories on Github.com

# %%
if __name__ == "__main__":
    browser = webdriver.Chrome()
    browser.get("https://github.com/")

    #Goto trending by first clicking on Explore tab and then click Trending
    xpath = '//summary[@class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block"]'
    browser.find_elements_by_xpath(xpath)[1].click()
    time.sleep(2)
    browser.find_element_by_link_text("Trending").click()

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")

    articles = soup.find_all("article", {"class":"Box-row"})

    for article in articles:
        try:
            repo_title = article.find("h1").text.split("/")[1].strip()
        except:
            repo_title = ""

        try:
            repo_des = article.find("p").text.strip()
        except:
            repo_des = ""

        try:
            contri_count = article.find("span",{"class":"d-inline-block mr-3"})
            contri_count = len(contri_count.find_all("a"))
        except:
            contri_count = 1
        try:
            languages = article.find("span",{"itemprop":"programmingLanguage"}).text.strip()
        except:
            languages = ""

        print(repo_title, repo_des, contri_count, languages)
        print()
# Out:
# algorithm-base 专门为刚开始刷题的同学准备的算法基地，没有最细只有更细，立志用动画将晦涩难懂的算法说的通俗易懂！ 5 Java
#
# javascript-algorithms Algorithms and data structures implemented in JavaScript with explanations and links to further readings 5 JavaScript
#
# javascript JavaScript Style Guide 5 JavaScript
#
# 30-seconds-of-code Short JavaScript code snippets for all your development needs 5 JavaScript
#
# earthly Build automation for the container era 5 Go
#
# nvm Node Version Manager - POSIX-compliant bash script to manage multiple active node.js versions 5 Shell
#
# IoT-For-Beginners 12 Weeks, 24 Lessons, IoT for All! 5 C++
#
# wifi-card Print a QR code for connecting to your WiFi 4 JavaScript
#
# Incident-Playbook GOAL: Incident Response Playbooks Mapped to MITRE Attack Tactics and Techniques. [Contributors Friendly] 3 Python
#
# clean-code-javascript Clean Code concepts adapted for JavaScript 5 JavaScript
#
# javascript-questions A long list of (advanced) JavaScript questions, and their explanations 5
#
# awesome-javascript A collection of awesome browser-side JavaScript libraries, resources and shiny things. 5
#
# awesome-mac  Now we have become very big, Different from the original idea. Collect premium software in various categories. 5 JavaScript
#
# kratos A Go framework for microservices. 5 Go
#
# Anime-Girls-Holding-Programming-Books Anime Girls Holding Programming Books 5
#
# PayloadsAllTheThings A list of useful payloads and bypass for Web Application Security and Pentest/CTF 5 Python
#
# nodebestpractices The Node.js best practices list (June 2021) 5 JavaScript
#
# faker2 不知名大佬备份 1 JavaScript
#
# alias-free-gan-pytorch Unofficial implementation of Alias-Free Generative Adversarial Networks. (https://arxiv.org/abs/2106.12423) in PyTorch 2 Python
#
# awesome-fenix 讨论如何构建一套可靠的大型分布式系统 5 Vue
#
# Yolov5_DeepSort_Pytorch Real-time multi-object tracker using YOLO v5 and deep sort 2 Python
#
# flutter_ecommerce_app E-Commerce App built in flutter 3 Dart
#
# folly An open-source C++ library developed and used at Facebook. 5 C++
#
# social-distancing-ios Taiwan Social Distancing App - iOS 3 Swift
#
# Awesome-JavaScript-Projects This Repository contain awesome vanilla JavaScript projects. 5 JavaScript

# %% [markdown]
# 6.Scrape the details of top 100 songs on billboard.com.

# %%
if __name__=="__main__":
    browser = webdriver.Chrome()
    browser.get("https://www.billboard.com/")
    browser.find_element_by_link_text("CHARTS").click()
    time.sleep(5)
    browser.find_element_by_link_text("Hot 100").click()

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")

    ol = soup.find("ol",{"class":"chart-list__elements"})
    lis = ol.find_all("li")

    for li in lis:
        try:
            name = li.find("span",{"class":"chart-element__information__song text--truncate color--primary"}).text.strip()
        except:
            name = ""

        try:   
            artist = li.find("span",{"class":"chart-element__information__artist text--truncate color--secondary"}).text.strip()
        except:
            artist = ""
        
        try:
            last_week = li.find("div",{"class":"chart-element__meta text--center color--secondary text--last"}).text.strip()
        except:
            last_week = ""

        try:
            peak_rank = li.find("div",{"class":"chart-element__meta text--center color--secondary text--peak"}).text.strip()
        except:
            peak_rank = ""

        try:
            weeks_on_board = li.find("div",{"class":"chart-element__meta text--center color--secondary text--week"}).text.strip()
        except:
            weeks_on_board = ""

        print(name, artist, last_week, peak_rank, weeks_on_board)
        print()

# %% [markdown]
# 7.Scrape the details of Data science recruiters from naukri.com.

# %%
if __name__=="__main__":
    browser = webdriver.Chrome()
    browser.get("https://www.naukri.com/")
    wait = WebDriverWait(browser, 600)

    #Goto recruiters tab
    xpath = '//*[@id="root"]/div[1]/div/ul[1]/li[2]/a/div'
    browser.find_element_by_xpath(xpath).click()

    #Goto the active tab
    window_name = browser.window_handles[1]
    browser.switch_to.window(window_name=window_name)

    #Search for Data Science in search box
    xpath = '//*[@class="sugInp"]'
    search_box = wait.until(ec.element_to_be_clickable((By.XPATH, xpath)))
    search_box.send_keys("Data Science"+Keys.ENTER)

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")

    divs = soup.find_all("div",{"class":"recInfo"})

    for div in divs:
        para = div.find("p",{"class":"highlightable"}).text.strip()
        skills = div.find("div",{"class":"hireSec highlightable"}).text.strip()
        print(para)
        print(skills)
        print()
# Out:
# Aakash Harit HR Manager Data Science Network Delhi
# Classic ASP Developer,   Internet Marketing Professional,   Data Science SME,   Content Writers,   SEO Professional,   Revenue Professional
#
# shravan Kumar Gaddam Company Recruiter Shore Infotech India Pvt. Ltd Hyderabad / Secunderabad
# .Net,   Java,   Data Science,   Linux Administration,   Sql Server Development,   Winforms,   Wcf Services,   Wpf,   Telecom Engineering,   Technical Management,   Software
#
# MARSIAN Technologies LLP Company HR MARSIAN Technologies LLP Pune
# Data Science,   Artificial Intelligence,   Machine Learning,   Business Analytics
#
# Anik Agrawal Company Recruiter Enerlytics Software Solutions Pvt Ltd Ahmedabad
# Mean Stack,   javascript,   angularjs,   mongodb,   Web Services,   rest,   express,   Node.js,   Big Data,   iot,   Data Science,   Cloud Computing,   saas,   Aws
#
# subhas patel Founder CEO LibraryXProject UK - (london)
# Hadoop,   Spark,   Digital Strategy,   Data Architecture,   Command Center,   Cdp,   Dmp,   Kafka,   Data Science,   Data Analysis,   Big Data Analytics,   Real Time Analysis,   SQL
#
# Abhishek - Only Analytics Hiring - India and  Recruitment Lead Consultant Apidel Technologies Division of Transpower Vadodara / Baroda
# Analytics,   Business Intelligence,   Business Analytics,   Predictive Modeling,   Predictive Analytics,   Data Science,   Data Analysis,   Data Analytics,   Big Data,   Big
#
# Institute for Financial Management and Resear Programme Manager IFMR Chennai
# Data Science
#
# Balu Ramesh HR Administrator Techvantage Systems Pvt Ltd Trivandrum
# Machine Learning,   algorithms,   Go Getter,   Computer Science,   spark,   Big Data,   hdfs,   sql,   cassandra,   hadoop,   python,   scala,   java,   Data Science,   Front End
#
# Asif Lucknowi Director Weupskill- Live Wire India Indore
# Technical Training,   Software Development,   Presentation Skills,   B.tech,   M.tech,   B.e.,   mca,   msc,   Computer Science,   freshers,   jobs in indore,   Data Science,   itil
#
# InstaFinancials Human Resource CBL Data Science Private Limited Bengaluru / Bangalore
# Software Development,   It Sales,   Account Management,   Data Analysis,   Customer Service,   Sr,   Software Engineering,   Mvc,   Ajax,   Asp.net,   Html,   C#,   Javascript
#
# Kalpana Dumpala Executive Hiring Innominds Software Hyderabad / Secunderabad
# Qa,   Ui/ux,   Java Developer,   Java Architect,   C++/qt,   Php,   Lamp,   Api,   J2ee,   Java,   Soa,   Esb,   Middleware,   Bigdata Achitect,   Hadoop Architect,   Deep
#
# Mubarak Company HR MoneyTap Bengaluru / Bangalore
# Business Intelligence,   Data Warehousing,   Data Science,   Business Analytics,   Customer Support,   Business Reporting,   Bi
#
# Kushal Rastogi Company HR QuantMagnum Technologies Pvt. Ltd. Mumbai
# Office Administration,   Hr Administration,   telecalling,   client relationship management,   Client Acquisition,   Sales,   Reception,   HR,   Recruitment,   Onboarding,   Human
#
# Ruchi Dhote Senior Executive Talent Acquisition Bristlecone India Ltd Pune
# Qlikview,   Qlik Sense,   Microsoft Azure,   Power Bi,   Data Science,   Machine Learning
#
# Mahesh Babu Channa HR Team Lead SocialPrachar.com Hyderabad / Secunderabad
# Social Media,   digital media maketing,   seo,   smm,   smo,   sem,   Content Wirting,   social media marketing,   social media manager,   digital media marketing manager
#
# Kapil Devang HR Manager BISP Solutions Bhopal
# Big Data,   Hadoop,   Data Analytics,   Data Science
#
# Manisha Yadav HR Executive Easi Tax Navi Mumbai
# Telecalling,   Client Interaction,   Marketing,   Research,   Web Development,   Social Media Marketing,   Data Entry Operation,   Excel,   Ms Office,   Invoicing
#
# Riya Rajesh Manager Talent Acquisition Novelworx Digital Solutions Cochin
# Data Science
#
# Rashmi Bhattacharjee HR Head AXESTRACK SOFTWARE SOLUTIONS PRIVATE... Delhi
# Corporate Sales,   Software Development,   Software Sales,   Marketing,   Creative Designing,   Corporate Planning,   Senior Management,   Crm,   Client Relationship
#
# Faizan Kareem HR MANAGER FirstTech Consaltants Pvt.Ltd Hyderabad / Secunderabad
# Data Analytics,   Data Science,   Machine Learning,   Deep Learning,   Nlp,   Data Mining,   Python,   R,   Database Administration,   Text Mining
#
# Rithika dadwal HR Recruiter Affine Analytics Pune
# Data Science,   Machine Learning,   Python,   R,   Deep Learning,   Big Data,   Hadoop
#
# Azahar Shaikh Company Recruiter NEAL ANALYTICS SERVICES PVT LTD Pune
# Data Science,   Artificial Intelligence,   Machine Learning,   Data Analytics
#
# Sandhya Khandagale HR Recruiter Compumatrice Multimedia Pvt Ltd Pune
# Big Data,   Data Science,   Artificial Intelligence,   Hadoop,   Ui Development,   Php,   Freelancing,   .Net,   Software Testing,   Sap,   Leadership Hiring
#
# Shaun Rao Manager Human Resources Exela Technologies Pune
# Java,   Net,   Angularjs,   Hr,   Infrastructure,   Management,   Project Management,   Business Analysis,   Data Science,   Information Technology,   Technology
#
# Manas Lead Talent acquisition Autumn Leaf Consulting Services Private... Bengaluru / Bangalore
# Software Architecture,   Vp Engineering,   Product Management,   analytics,   Data Science,   Node.js,   Principal Engineer,   Big Data,   python,   angularjs,   React.js
#
# kumar Proprietor trainin Bengaluru / Bangalore
# Data Science,   Hadoop,   Rpas,   Devops,   Python,   Aws,   Teaching,   Big Data
#
# Sunil Vedula CEO Nanoprecise Sci Corp
# Signal Processing,   Machine Learning,   Neural Networks,   Data Science,   Predictive Analytics,   Time Series Analysis,   Data Visualization,   Technical Leadership,   Data
#
# Rajat Kumar Founder CEO R.S Consultancy &amp; Services Delhi
# Web Technologies,   Project Management,   Software Architecture,   Data Science,   Object Oriented Programming,   Computer Science,   Electrical Engineering,   Architecture
#
# Priya Khare Senior Manager Independent Consultant Bengaluru / Bangalore
# Data Science,   Artificial Intelligence,   analytics,   Business Intelligence,   python,   tableau,   Power Bi,   qlikview,   sql,   Data Warehousing,   Data Visualization
#
# Dhruv Dev Dubey Company Recruitment Head Confidential Bengaluru / Bangalore
# Server Administartion,   Verilog,   Vhdl,   Digital Marketing,   Market Research,   Property Research,   Legal,   It And Non It Recruitment,   Logistics,   Supply Chain,   Bfsi
#
# Jayanth N Project Manager Dollarbird Information Services Pvt, Ltd Mysoru / Mysore
# Data Analytics,   Managed Services,   Team Leading,   python,   Machine Learning,   Google Analytics,   Dmp,   Aws,   Campaign Analytics,   Digital Campaigns,   Audience
#
# SREEDHAR Recruitment Consultant JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED Hyderabad / Secunderabad
# Data Science,   Machine Learning,   Big Data Analytics,   Spark,   Python,   R,   Networking,   Network Engineering,   Placement,   Training,   Sql,   Marketing,   Mainframes,   All
#
# Radha Manivasagam HR Executive Techcovery Bengaluru / Bangalore
# Python,   Artificial Intelligence,   Machine Learning,   Data Science
#
# Ravi Dubey Recruitment Manager HyrEzy Talent Solutions LLP Ghaziabad
# Walmart Interra Skeps Expressstores indifi whitehatJr Practo Zylo Doctalk Medtrail
#
# Prateek Kumar Head Trisect Noida
# Java,   Python,   Angularjs,   Software Testing,   Machine Learning,   Data Science,   Javascript,   Django,   React.js,   Node.js,   Augmented Reality,   Virtual Reality,   Advanced
#
# Amit Sharma Consultant ASCO consulting New Delhi
# Machine Learning,   Artificial Intelligence,   Data Science,   Software Engineering,   Software Development,   Graduate Engineer Trainee,   Fresher,   Data Analytics,   Java
#
# Kanan senior technology instructor NY INST Chennai
# C,   C++,   Artificial Intelligence,   Python,   Php,   Web Development,   Matlab,   Data Science,   Augmented Reality,   C C++
#
# Shashikant Chaudhary HR Recruiter/HR Excutive 3D India Staffing Research &amp; Consulting... Aligarh
# Relationship Management,   Retail Sales,   Private Banking,   Mutual Funds,   NISM,   Equity,   Finance,   Financial Products,   Financial Services,   Verbal,   Written
#
# Brad Manager, Technical Recruiting O.C. Tanner Salt Lake City
# Data Science,   Software Engineering
#
# Rutuja Pawar Technical Recruiter Demand Matrix Pune
# Data Science,   Big Data Analytics,   Digital Marketing,   Content Writing,   Ui Development,   Database Development,   Qa Automation,   Python,   Project Management
#
# Madhusudhan Sridhar Erp Implementer MADHUSUDHAN SRIDHAR Bengaluru / Bangalore
# Data Science,   Recruitment,   Salary
#
# Ankit Sinha Head Analytics Suntech Global Mumbai
# B.Tech,   Tableau,   Statistics,   R,   Analytics,   Time Series,   Data Science,   Business Solutions,   SQL,   Technical Skills,   SSAS,   SQL Server,   Analysis Services,   Qlikview
#
# Gaurav Chouhan Chief Technical Officer Strategic Consulting Lab Indore
# Software Development,   Business Intelligence,   Big Data Analytics,   Database Administration,   Data Science,   Microsoft Azure,   Spark,   Cassandra,   Object Oriented
#
# Rashi Kacker Sr Product Manager Impel Labs Pvt. Ltd. Bengaluru / Bangalore
# Data Science,   Node.js,   Angularjs
#
# Ashwini Director Global Delivery MRP Advisers MYSORE
# Data Science,   Media Marketing,   Resource Planning,   Managed Services,   Display Advertising,   Machine Learning,   Python,   Etl,   Sql
#
# Balaji Kolli Co Founder Saras Solutions India Pvt Ltd Hyderabad / Secunderabad
# Data Analysis,   Learning,   Data Science,   Computer Science,   Communication Skills
#
# Rajani Nagaraj HR Manager WildJasmine Bengaluru / Bangalore
# Java,   Hadoop,   R,   Machine Learning,   Spark,   Flume,   Hdfs,   Data Mining,   Sas,   Big,   Data Science,   Cloudera,   Impala,   Bigdata
#
# ROHIT Kumar Architect LNT Private Limited Mumbai
# Software Development,   Core Java,   Unit Testing,   Customer Experience,   Problem Solving,   Communication Skills,   Mysql,   Data Science,   Sales Management,   Analytics
#
# Amir Chowdhury Managing Partner Granular.ai
# Machine Learning,   Data Science,   Product Management,   New Product,   Data Analysis,   Computer Vision,   Deep Learning,   Python,   Remote Sensing
#
# Shailja Mishra HR Manager Certybox Pvt.Ltd. Noida
# consulting,   Education Counseling,   Educational Sales,   Institutional Sales,   pmp,   Data Science,   Business Development,   Revenue Generation,   Sales Achievement,   new

# %% [markdown]
# 8.Scrape the details of Highest selling novels.

# %%
if __name__ == "__main__":
    browser = webdriver.Chrome()
    browser.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/")

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")

    table = soup.find("table",{"class":"in-article sortable"})
    rows = table.find_all("tr")
    #Delete header row
    rows.pop(0)
    rows.pop(0)

    for row in rows:
        row = row.text.split("\n")

        book = row[2]
        author = row[3]
        volumes_sold = row[4]
        publisher = row[5]
        genre = row[6]

        print(book)
        print(author)
        print(volumes_sold)
        print(publisher)
        print(genre)
        print()
# Out:
#  Da Vinci Code,The
#  Brown, Dan
#  5,094,805
#  Transworld
#  Crime, Thriller & Adventure
#
#  Harry Potter and the Deathly Hallows
#  Rowling, J.K.
#  4,475,152
#  Bloomsbury
#  Children's Fiction
#
#  Harry Potter and the Philosopher's Stone
#  Rowling, J.K.
#  4,200,654
#  Bloomsbury
#  Children's Fiction
#
#  Harry Potter and the Order of the Phoenix
#  Rowling, J.K.
#  4,179,479
#  Bloomsbury
#  Children's Fiction
#
#  Fifty Shades of Grey
#  James, E. L.
#  3,758,936
#  Random House
#  Romance & Sagas
#
#  Harry Potter and the Goblet of Fire
#  Rowling, J.K.
#  3,583,215
#  Bloomsbury
#  Children's Fiction
#
#  Harry Potter and the Chamber of Secrets
#  Rowling, J.K.
#  3,484,047
#  Bloomsbury
#  Children's Fiction
#
#  Harry Potter and the Prisoner of Azkaban
#  Rowling, J.K.
#  3,377,906
#  Bloomsbury
#  Children's Fiction
#
#  Angels and Demons
#  Brown, Dan
#  3,193,946
#  Transworld
#  Crime, Thriller & Adventure
#
#  Harry Potter and the Half-blood Prince:Children's Edition
#  Rowling, J.K.
#  2,950,264
#  Bloomsbury
#  Children's Fiction
#
#  Fifty Shades Darker
#  James, E. L.
#  2,479,784
#  Random House
#  Romance & Sagas
#
#  Twilight
#  Meyer, Stephenie
#  2,315,405
#  Little, Brown Book
#  Young Adult Fiction
#
#  Girl with the Dragon Tattoo,The:Millennium Trilogy
#  Larsson, Stieg
#  2,233,570
#  Quercus
#  Crime, Thriller & Adventure
#
#  Fifty Shades Freed
#  James, E. L.
#  2,193,928
#  Random House
#  Romance & Sagas
#
#  Lost Symbol,The
#  Brown, Dan
#  2,183,031
#  Transworld
#  Crime, Thriller & Adventure
#
#  New Moon
#  Meyer, Stephenie
#  2,152,737
#  Little, Brown Book
#  Young Adult Fiction
#
#  Deception Point
#  Brown, Dan
#  2,062,145
#  Transworld
#  Crime, Thriller & Adventure
#
#  Eclipse
#  Meyer, Stephenie
#  2,052,876
#  Little, Brown Book
#  Young Adult Fiction
#
#  Lovely Bones,The
#  Sebold, Alice
#  2,005,598
#  Pan Macmillan
#  General & Literary Fiction
#
#  Curious Incident of the Dog in the Night-time,The
#  Haddon, Mark
#  1,979,552
#  Random House
#  General & Literary Fiction
#
#  Digital Fortress
#  Brown, Dan
#  1,928,900
#  Transworld
#  Crime, Thriller & Adventure
#
#  Short History of Nearly Everything,A
#  Bryson, Bill
#  1,852,919
#  Transworld
#  Popular Science
#
#  Girl Who Played with Fire,The:Millennium Trilogy
#  Larsson, Stieg
#  1,814,784
#  Quercus
#  Crime, Thriller & Adventure
#
#  Breaking Dawn
#  Meyer, Stephenie
#  1,787,118
#  Little, Brown Book
#  Young Adult Fiction
#
#  Very Hungry Caterpillar,The:The Very Hungry Caterpillar
#  Carle, Eric
#  1,783,535
#  Penguin
#  Picture Books
#
#  Gruffalo,The
#  Donaldson, Julia
#  1,781,269
#  Pan Macmillan
#  Picture Books
#
#  Jamie's 30-Minute Meals
#  Oliver, Jamie
#  1,743,266
#  Penguin
#  Food & Drink: General
#
#  Kite Runner,The
#  Hosseini, Khaled
#  1,629,119
#  Bloomsbury
#  General & Literary Fiction
#
#  One Day
#  Nicholls, David
#  1,616,068
#  Hodder & Stoughton
#  General & Literary Fiction
#
#  Thousand Splendid Suns,A
#  Hosseini, Khaled
#  1,583,992
#  Bloomsbury
#  General & Literary Fiction
#
#  Girl Who Kicked the Hornets' Nest,The:Millennium Trilogy
#  Larsson, Stieg
#  1,555,135
#  Quercus
#  Crime, Thriller & Adventure
#
#  Time Traveler's Wife,The
#  Niffenegger, Audrey
#  1,546,886
#  Random House
#  General & Literary Fiction
#
#  Atonement
#  McEwan, Ian
#  1,539,428
#  Random House
#  General & Literary Fiction
#
#  Bridget Jones's Diary:A Novel
#  Fielding, Helen
#  1,508,205
#  Pan Macmillan
#  General & Literary Fiction
#
#  World According to Clarkson,The
#  Clarkson, Jeremy
#  1,489,403
#  Penguin
#  Humour: Collections & General
#
#  Captain Corelli's Mandolin
#  Bernieres, Louis de
#  1,352,318
#  Random House
#  General & Literary Fiction
#
#  Sound of Laughter,The
#  Kay, Peter
#  1,310,207
#  Random House
#  Autobiography: General
#
#  Life of Pi
#  Martel, Yann
#  1,310,176
#  Canongate
#  General & Literary Fiction
#
#  Billy Connolly
#  Stephenson, Pamela
#  1,231,957
#  HarperCollins
#  Biography: The Arts
#
#  Child Called It,A
#  Pelzer, Dave
#  1,217,712
#  Orion
#  Autobiography: General
#
#  Gruffalo's Child,The
#  Donaldson, Julia
#  1,208,711
#  Pan Macmillan
#  Picture Books
#
#  Angela's Ashes:A Memoir of a Childhood
#  McCourt, Frank
#  1,204,058
#  HarperCollins
#  Autobiography: General
#
#  Birdsong
#  Faulks, Sebastian
#  1,184,967
#  Random House
#  General & Literary Fiction
#
#  Northern Lights:His Dark Materials S.
#  Pullman, Philip
#  1,181,503
#  Scholastic Ltd.
#  Young Adult Fiction
#
#  Labyrinth
#  Mosse, Kate
#  1,181,093
#  Orion
#  General & Literary Fiction
#
#  Harry Potter and the Half-blood Prince
#  Rowling, J.K.
#  1,153,181
#  Bloomsbury
#  Science Fiction & Fantasy
#
#  Help,The
#  Stockett, Kathryn
#  1,132,336
#  Penguin
#  General & Literary Fiction
#
#  Man and Boy
#  Parsons, Tony
#  1,130,802
#  HarperCollins
#  General & Literary Fiction
#
#  Memoirs of a Geisha
#  Golden, Arthur
#  1,126,337
#  Random House
#  General & Literary Fiction
#
#  No.1 Ladies' Detective Agency,The:No.1 Ladies' Detective Agency S.
#  McCall Smith, Alexander
#  1,115,549
#  Little, Brown Book
#  Crime, Thriller & Adventure
#
#  Island,The
#  Hislop, Victoria
#  1,108,328
#  Headline
#  General & Literary Fiction
#
#  PS, I Love You
#  Ahern, Cecelia
#  1,107,379
#  HarperCollins
#  General & Literary Fiction
#
#  You are What You Eat:The Plan That Will Change Your Life
#  McKeith, Gillian
#  1,104,403
#  Penguin
#  Fitness & Diet
#
#  Shadow of the Wind,The
#  Zafon, Carlos Ruiz
#  1,092,349
#  Orion
#  General & Literary Fiction
#
#  Tales of Beedle the Bard,The
#  Rowling, J.K.
#  1,090,847
#  Bloomsbury
#  Children's Fiction
#
#  Broker,The
#  Grisham, John
#  1,087,262
#  Random House
#  Crime, Thriller & Adventure
#
#  Dr. Atkins' New Diet Revolution:The No-hunger, Luxurious Weight Loss P
#  Atkins, Robert C.
#  1,054,196
#  Random House
#  Fitness & Diet
#
#  Subtle Knife,The:His Dark Materials S.
#  Pullman, Philip
#  1,037,160
#  Scholastic Ltd.
#  Young Adult Fiction
#
#  Eats, Shoots and Leaves:The Zero Tolerance Approach to Punctuation
#  Truss, Lynne
#  1,023,688
#  Profile Books Group
#  Usage & Writing Guides
#
#  Delia's How to Cook:(Bk.1)
#  Smith, Delia
#  1,015,956
#  Random House
#  Food & Drink: General
#
#  Chocolat
#  Harris, Joanne
#  1,009,873
#  Transworld
#  General & Literary Fiction
#
#  Boy in the Striped Pyjamas,The
#  Boyne, John
#  1,004,414
#  Random House Childrens Books G
#  Young Adult Fiction
#
#  My Sister's Keeper
#  Picoult, Jodi
#  1,003,780
#  Hodder & Stoughton
#  General & Literary Fiction
#
#  Amber Spyglass,The:His Dark Materials S.
#  Pullman, Philip
#  1,002,314
#  Scholastic Ltd.
#  Young Adult Fiction
#
#  To Kill a Mockingbird
#  Lee, Harper
#  998,213
#  Random House
#  General & Literary Fiction
#
#  Men are from Mars, Women are from Venus:A Practical Guide for Improvin
#  Gray, John
#  992,846
#  HarperCollins
#  Popular Culture & Media: General Interest
#
#  Dear Fatty
#  French, Dawn
#  986,753
#  Random House
#  Autobiography: The Arts
#
#  Short History of Tractors in Ukrainian,A
#  Lewycka, Marina
#  986,115
#  Penguin
#  General & Literary Fiction
#
#  Hannibal
#  Harris, Thomas
#  970,509
#  Random House
#  Crime, Thriller & Adventure
#
#  Lord of the Rings,The
#  Tolkien, J. R. R.
#  967,466
#  HarperCollins
#  Science Fiction & Fantasy
#
#  Stupid White Men:...and Other Sorry Excuses for the State of the Natio
#  Moore, Michael
#  963,353
#  Penguin
#  Current Affairs & Issues
#
#  Interpretation of Murder,The
#  Rubenfeld, Jed
#  962,515
#  Headline
#  Crime, Thriller & Adventure
#
#  Sharon Osbourne Extreme:My Autobiography
#  Osbourne, Sharon
#  959,496
#  Little, Brown Book
#  Autobiography: The Arts
#
#  Alchemist,The:A Fable About Following Your Dream
#  Coelho, Paulo
#  956,114
#  HarperCollins
#  General & Literary Fiction
#
#  At My Mother's Knee ...:and Other Low Joints
#  O'Grady, Paul
#  945,640
#  Transworld
#  Autobiography: The Arts
#
#  Notes from a Small Island
#  Bryson, Bill
#  931,312
#  Transworld
#  Travel Writing
#
#  Return of the Naked Chef,The
#  Oliver, Jamie
#  925,425
#  Penguin
#  Food & Drink: General
#
#  Bridget Jones: The Edge of Reason
#  Fielding, Helen
#  924,695
#  Pan Macmillan
#  General & Literary Fiction
#
#  Jamie's Italy
#  Oliver, Jamie
#  906,968
#  Penguin
#  National & Regional Cuisine
#
#  I Can Make You Thin
#  McKenna, Paul
#  905,086
#  Transworld
#  Fitness & Diet
#
#  Down Under
#  Bryson, Bill
#  890,847
#  Transworld
#  Travel Writing
#
#  Summons,The
#  Grisham, John
#  869,671
#  Random House
#  Crime, Thriller & Adventure
#
#  Small Island
#  Levy, Andrea
#  869,659
#  Headline
#  General & Literary Fiction
#
#  Nigella Express
#  Lawson, Nigella
#  862,602
#  Random House
#  Food & Drink: General
#
#  Brick Lane
#  Ali, Monica
#  856,540
#  Transworld
#  General & Literary Fiction
#
#  Memory Keeper's Daughter,The
#  Edwards, Kim
#  845,858
#  Penguin
#  General & Literary Fiction
#
#  Room on the Broom
#  Donaldson, Julia
#  842,535
#  Pan Macmillan
#  Picture Books
#
#  About a Boy
#  Hornby, Nick
#  828,215
#  Penguin
#  General & Literary Fiction
#
#  My Booky Wook
#  Brand, Russell
#  820,563
#  Hodder & Stoughton
#  Autobiography: The Arts
#
#  God Delusion,The
#  Dawkins, Richard
#  816,907
#  Transworld
#  Popular Science
#
#  "Beano" Annual,The
#  0
#  816,585
#  D.C. Thomson
#  Children's Annuals
#
#  White Teeth
#  Smith, Zadie
#  815,586
#  Penguin
#  General & Literary Fiction
#
#  House at Riverton,The
#  Morton, Kate
#  814,370
#  Pan Macmillan
#  General & Literary Fiction
#
#  Book Thief,The
#  Zusak, Markus
#  809,641
#  Transworld
#  General & Literary Fiction
#
#  Nights of Rain and Stars
#  Binchy, Maeve
#  808,900
#  Orion
#  General & Literary Fiction
#
#  Ghost,The
#  Harris, Robert
#  807,311
#  Random House
#  General & Literary Fiction
#
#  Happy Days with the Naked Chef
#  Oliver, Jamie
#  794,201
#  Penguin
#  Food & Drink: General
#
#  Hunger Games,The:Hunger Games Trilogy
#  Collins, Suzanne
#  792,187
#  Scholastic Ltd.
#  Young Adult Fiction
#
#  Lost Boy,The:A Foster Child's Search for the Love of a Family
#  Pelzer, Dave
#  791,507
#  Orion
#  Biography: General
#
#  Jamie's Ministry of Food:Anyone Can Learn to Cook in 24 Hours
#  Oliver, Jamie
#  791,095
#  Penguin
#  Food & Drink: General

# %% [markdown]
# 9.Scrape the details most watched tv series of all time from imdb.com

# %%
if __name__=="__main__":
    browser = webdriver.Chrome()
    browser.get("https://www.imdb.com/list/ls095964455/")

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")

    divs = soup.find_all("div",{"class":"lister-item-content"})

    for div in divs:
        div = div.text.split("\n")
        div = [d for d in div if len(d)>1]
        name = div[1]
        year_span = div[2]
        genre = div[5]
        run_time = div[4]
        ratings = div[6]
        votes = div[-1]
 
        print(name)
        print(year_span)
        print(genre)
        print(run_time)
        print(ratings)
        print(votes)

        print()
# Out:
# Game of Thrones
# (2011–2019)
# Action, Adventure, Drama
# 57 min
# 9.2
# 1,834,809
#
# Stranger Things
# (2016– )
# Drama, Fantasy, Horror
# 51 min
# 8.7
# 873,590
#
# The Walking Dead
# (2010–2022)
# Drama, Horror, Thriller
# 44 min
# 8.2
# 879,023
#
# 13 Reasons Why
# (2017–2020)
# Drama, Mystery, Thriller
# 60 min
# 7.6
# 264,132
#
# The 100
# (2014–2020)
# Drama, Mystery, Sci-Fi
# 43 min
# 7.6
# 225,658
#
# Orange Is the New Black
# (2013–2019)
# Comedy, Crime, Drama
# 59 min
# Rate
# 283,485
#
# Riverdale
# (2017– )
# Crime, Drama, Mystery
# 45 min
# 6.8
# 125,028
#
# Grey's Anatomy
# (2005– )
# Drama, Romance
# 41 min
# 7.5
# 263,535
#
# The Flash
# (2014– )
# Action, Adventure, Drama
# 43 min
# 7.6
# 316,787
#
# Arrow
# (2012–2020)
# Action, Adventure, Crime
# 42 min
# 7.5
# 413,374
#
# Money Heist
# (2017–2021)
# Action, Crime, Mystery
# 70 min
# 8.3
# 337,187
#
# The Big Bang Theory
# (2007–2019)
# Comedy, Romance
# 22 min
# 8.1
# 740,307
#
# Black Mirror
# (2011– )
# Drama, Sci-Fi, Thriller
# 60 min
# 8.8
# 465,850
#
# Sherlock
# (2010–2017)
# Crime, Drama, Mystery
# 88 min
# 9.1
# 834,491
#
# Vikings
# (2013–2020)
# Action, Adventure, Drama
# 44 min
# 8.5
# 455,313
#
# Pretty Little Liars
# (2010–2017)
# Drama, Mystery, Romance
# 44 min
# 7.4
# 155,200
#
# The Vampire Diaries
# (2009–2017)
# Drama, Fantasy, Horror
# 43 min
# 7.7
# 291,987
#
# American Horror Story
# (2011– )
# Drama, Horror, Thriller
# 60 min
# Rate
# 283,875
#
# Breaking Bad
# (2008–2013)
# Crime, Drama, Thriller
# 49 min
# 9.4
# 1,538,753
#
# Lucifer
# (2016– )
# Crime, Drama, Fantasy
# 42 min
# 8.1
# 258,510
#
# Supernatural
# (2005–2020)
# Drama, Fantasy, Horror
# 44 min
# 8.4
# 401,638
#
# Prison Break
# (2005–2017)
# Action, Crime, Drama
# 44 min
# 8.3
# 490,005
#
# How to Get Away with Murder
# (2014–2020)
# Crime, Drama, Mystery
# 43 min
# 8.1
# 135,133
#
# Teen Wolf
# (2011–2017)
# Action, Drama, Fantasy
# 41 min
# 7.6
# 131,985
#
# The Simpsons
# (1989– )
# Animation, Comedy
# 22 min
# 8.6
# 373,653
#
# Once Upon a Time
# (2011–2018)
# Adventure, Fantasy, Romance
# 60 min
# 7.7
# 211,904
#
# Narcos
# (2015–2017)
# Biography, Crime, Drama
# 49 min
# 8.8
# 372,908
#
# Daredevil
# (2015–2018)
# Action, Crime, Drama
# 54 min
# 8.6
# 372,753
#
# Friends
# (1994–2004)
# Comedy, Romance
# 22 min
# 8.9
# 872,038
#
# How I Met Your Mother
# (2005–2014)
# Comedy, Romance
# 22 min
# 8.3
# 621,001
#
# Suits
# (2011–2019)
# Comedy, Drama
# 44 min
# 8.4
# 372,628
#
# Mr. Robot
# (2015–2019)
# Crime, Drama, Thriller
# 49 min
# 8.5
# 343,832
#
# The Originals
# (2013–2018)
# Drama, Fantasy, Horror
# 45 min
# 8.2
# 121,831
#
# Supergirl
# (2015–2021)
# Action, Adventure, Drama
# 43 min
# 6.2
# 114,729
#
# Gossip Girl
# (2007–2012)
# Drama, Romance
# 42 min
# 7.4
# 158,481
#
# Sense8
# (2015–2018)
# Drama, Mystery, Sci-Fi
# 60 min
# 8.3
# 143,400
#
# Gotham
# (2014–2019)
# Action, Crime, Drama
# 42 min
# 7.8
# 215,529
#
# Westworld
# (2016– )
# Drama, Mystery, Sci-Fi
# 62 min
# 8.6
# 441,969
#
# Jessica Jones
# (2015–2019)
# Action, Crime, Drama
# 56 min
# 7.9
# 197,051
#
# Modern Family
# (2009–2020)
# Comedy, Drama, Romance
# 22 min
# 8.4
# 373,871
#
# Rick and Morty
# (2013– )
# Animation, Adventure, Comedy
# 23 min
# 9.2
# 404,140
#
# Shadowhunters
# (2016–2019)
# Action, Drama, Fantasy
# 42 min
# 6.6
# 55,759
#
# The End of the F***ing World
# (2017–2019)
# Adventure, Comedy, Crime
# 25 min
# 8.1
# 156,014
#
# House of Cards
# (2013– )
# Drama
# 51 min
# 8.7
# 474,958
#
# Dark
# (2017–2020)
# Crime, Drama, Mystery
# 60 min
# 8.8
# 309,104
#
# Elite
# (2018– )
# Crime, Drama, Thriller
# 60 min
# 7.5
# 57,792
#
# Sex Education
# (2019– )
# Comedy, Drama
# 45 min
# 8.3
# 174,328
#
# Shameless
# (2011–2021)
# Comedy, Drama
# 46 min
# 8.5
# 212,076
#
# New Girl
# (2011–2018)
# Comedy
# 22 min
# 7.7
# 199,235
#
# Agents of S.H.I.E.L.D.
# (2013–2020)
# Action, Adventure, Drama
# 45 min
# 7.5
# 204,256
#
# You
# (2018– )
# Crime, Drama, Romance
# 45 min
# 7.7
# 155,653
#
# Dexter
# (2006–2021)
# Crime, Drama, Mystery
# 53 min
# 8.6
# 661,052
#
# Fear the Walking Dead
# (2015– )
# Drama, Horror, Sci-Fi
# 44 min
# 6.9
# 117,282
#
# Family Guy
# (1999–2022)
# Animation, Comedy
# 22 min
# 8.1
# 311,079
#
# The Blacklist
# (2013– )
# Crime, Drama, Mystery
# 43 min
# Rate
# 210,692
#
# Lost
# (2004–2010)
# Adventure, Drama, Fantasy
# 44 min
# 8.3
# 509,574
#
# Peaky Blinders
# (2013– )
# Crime, Drama
# 60 min
# 8.8
# 386,408
#
# House
# (2004–2012)
# Drama, Mystery
# 44 min
# 8.7
# 424,252
#
# Quantico
# (2015–2018)
# Crime, Drama, Mystery
# 42 min
# 6.7
# 57,989
#
# Orphan Black
# (2013–2017)
# Action, Drama, Sci-Fi
# 44 min
# 8.3
# 103,882
#
# Homeland
# (2011–2020)
# Crime, Drama, Mystery
# 55 min
# 8.3
# 321,206
#
# Blindspot
# (2015–2020)
# Action, Crime, Drama
# 42 min
# 7.4
# 67,960
#
# DC's Legends of Tomorrow
# (2016– )
# Action, Adventure, Drama
# 42 min
# 6.8
# 95,140
#
# The Handmaid's Tale
# (2017– )
# Drama, Sci-Fi, Thriller
# 60 min
# 8.4
# 191,730
#
# Chilling Adventures of Sabrina
# (2018–2020)
# Drama, Fantasy, Horror
# 60 min
# 7.5
# 81,869
#
# The Good Doctor
# (2017– )
# Drama
# 41 min
# 8.1
# 68,508
#
# Jane the Virgin
# (2014–2019)
# Comedy
# 60 min
# 7.8
# 41,185
#
# Glee
# (2009–2015)
# Comedy, Drama, Music
# 44 min
# 6.7
# 139,313
#
# South Park
# (1997– )
# Animation, Comedy
# 22 min
# 8.7
# 338,405
#
# Brooklyn Nine-Nine
# (2013–2022)
# Comedy, Crime
# 22 min
# 8.4
# 245,380
#
# Under the Dome
# (2013–2015)
# Drama, Mystery, Sci-Fi
# 43 min
# 6.6
# 102,384
#
# The Umbrella Academy
# (2019– )
# Action, Adventure, Comedy
# 60 min
# Rate
# 173,238
#
# True Detective
# (2014–2019)
# Crime, Drama, Mystery
# 55 min
# 8.9
# 512,823
#
# The OA
# (2016–2019)
# Drama, Fantasy, Mystery
# 60 min
# 7.8
# 94,083
#
# Desperate Housewives
# (2004–2012)
# Comedy, Drama, Mystery
# 45 min
# 7.5
# 119,156
#
# Better Call Saul
# (2015– )
# Crime, Drama
# 46 min
# 8.8
# 344,317
#
# Bates Motel
# (2013–2017)
# Drama, Horror, Mystery
# 45 min
# 8.1
# 99,742
#
# The Punisher
# (2017–2019)
# Action, Crime, Drama
# 53 min
# 8.5
# 192,946
#
# Atypical
# (2017–2021)
# Comedy, Drama
# 30 min
# 8.3
# 66,102
#
# Dynasty
# (2017– )
# Drama
# 42 min
# 7.3
# 16,396
#
# This Is Us
# (2016–2022)
# Comedy, Drama, Romance
# 45 min
# 8.7
# 115,408
#
# The Good Place
# (2016–2020)
# Comedy, Drama, Fantasy
# 22 min
# 8.2
# 125,690
#
# Iron Fist
# (2017–2018)
# Action, Adventure, Crime
# 55 min
# 6.5
# 118,068
#
# The Rain
# (2018–2020)
# Drama, Sci-Fi, Thriller
# 45 min
# 6.3
# 32,571
#
# Mindhunter
# (2017–2019)
# Crime, Drama, Thriller
# 60 min
# 8.6
# 232,984
#
# Revenge
# (2011–2015)
# Drama, Mystery, Thriller
# 44 min
# 7.8
# 114,455
#
# Luke Cage
# (2016–2018)
# Action, Crime, Drama
# 55 min
# 7.3
# 119,515
#
# Scandal
# (2012–2018)
# Drama, Thriller
# 43 min
# 7.7
# 68,455
#
# The Defenders
# (2017)
# Action, Adventure, Crime
# 50 min
# 7.3
# 93,897
#
# Big Little Lies
# (2017–2019)
# Crime, Drama, Mystery
# 60 min
# 8.5
# 166,581
#
# Insatiable
# (2018–2019)
# Comedy, Drama, Thriller
# 45 min
# 6.5
# 23,863
#
# The Mentalist
# (2008–2015)
# Crime, Drama, Mystery
# 43 min
# 8.1
# 169,442
#
# The Crown
# (2016– )
# Biography, Drama, History
# 58 min
# 8.6
# 167,864
#
# Chernobyl
# (2019)
# Drama, History, Thriller
# 330 min
# 9.4
# 588,928
#
# iZombie
# (2015–2019)
# Comedy, Crime, Drama
# 42 min
# 7.8
# 61,896
#
# Reign
# (2013–2017)
# Drama, Fantasy
# 42 min
# 7.5
# 44,778
#
# A Series of Unfortunate Events
# (2017–2019)
# Adventure, Comedy, Drama
# 50 min
# 7.8
# 55,385
#
# Criminal Minds
# (2005–2020)
# Crime, Drama, Mystery
# 42 min
# 8.1
# 169,485
#
# Scream: The TV Series
# (2015–2019)
# Comedy, Crime, Drama
# 45 min
# 7.1
# 35,114
#
# The Haunting of Hill House
# (2018)
# Drama, Horror, Mystery
# 572 min
# 8.6
# 193,265

# %% [markdown]
# 10.Details of Datasets from UCI machine learning repositories.

# %%
if __name__=="__main__":
    browser = webdriver.Chrome()
    browser.get("https://archive.ics.uci.edu/")
    time.sleep(5)
    browser.find_element_by_link_text("View ALL Data Sets").click()

    html = browser.page_source
    soup = BeautifulSoup(html, "html.parser")
    table = soup.find("table",{"border":1,"cellpadding":5})

    rows = table.find_all("tr")
    #Delete header row
    rows.pop(0)

    for row in rows:
        row = row.text.strip()
        print(row)
# Out:
# Abalone
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 4177
# 8
# 1995
# Abalone
# Adult
#
# Multivariate
# Classification
# Categorical, Integer
# 48842
# 14
# 1996
# Adult
# Annealing
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 798
# 38
# Annealing
# Anonymous Microsoft Web Data
#
#
# Recommender-Systems
# Categorical
# 37711
# 294
# 1998
# Anonymous Microsoft Web Data
# Arrhythmia
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 452
# 279
# 1998
# Arrhythmia
# Artificial Characters
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 6000
# 7
# 1992
# Artificial Characters
# Audiology (Original)
#
# Multivariate
# Classification
# Categorical
# 226
#
# 1987
# Audiology (Original)
# Audiology (Standardized)
#
# Multivariate
# Classification
# Categorical
# 226
# 69
# 1992
# Audiology (Standardized)
# Auto MPG
#
# Multivariate
# Regression
# Categorical, Real
# 398
# 8
# 1993
# Auto MPG
# Automobile
#
# Multivariate
# Regression
# Categorical, Integer, Real
# 205
# 26
# 1987
# Automobile
# Badges
#
# Univariate, Text
# Classification
#
# 294
# 1
# 1994
# Badges
# Balance Scale
#
# Multivariate
# Classification
# Categorical
# 625
# 4
# 1994
# Balance Scale
# Balloons
#
# Multivariate
# Classification
# Categorical
# 16
# 4
# Balloons
# Breast Cancer
#
# Multivariate
# Classification
# Categorical
# 286
# 9
# 1988
# Breast Cancer
# Breast Cancer Wisconsin (Original)
#
# Multivariate
# Classification
# Integer
# 699
# 10
# 1992
# Breast Cancer Wisconsin (Original)
# Breast Cancer Wisconsin (Prognostic)
#
# Multivariate
# Classification, Regression
# Real
# 198
# 34
# 1995
# Breast Cancer Wisconsin (Prognostic)
# Breast Cancer Wisconsin (Diagnostic)
#
# Multivariate
# Classification
# Real
# 569
# 32
# 1995
# Breast Cancer Wisconsin (Diagnostic)
# Pittsburgh Bridges
#
# Multivariate
# Classification
# Categorical, Integer
# 108
# 13
# 1990
# Pittsburgh Bridges
# Car Evaluation
#
# Multivariate
# Classification
# Categorical
# 1728
# 6
# 1997
# Car Evaluation
# Census Income
#
# Multivariate
# Classification
# Categorical, Integer
# 48842
# 14
# 1996
# Census Income
# Chess (King-Rook vs. King-Knight)
#
# Multivariate, Data-Generator
# Classification
# Categorical, Integer
#
# 22
# 1988
# Chess (King-Rook vs. King-Knight)
# Chess (King-Rook vs. King-Pawn)
#
# Multivariate
# Classification
# Categorical
# 3196
# 36
# 1989
# Chess (King-Rook vs. King-Pawn)
# Chess (King-Rook vs. King)
#
# Multivariate
# Classification
# Categorical, Integer
# 28056
# 6
# 1994
# Chess (King-Rook vs. King)
# Chess (Domain Theories)
#
# Domain-Theory
# Chess (Domain Theories)
# Bach Chorales
#
# Univariate, Time-Series
#
# Categorical, Integer
# 100
# 6
# Bach Chorales
# Connect-4
#
# Multivariate, Spatial
# Classification
# Categorical
# 67557
# 42
# 1995
# Connect-4
# Credit Approval
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 690
# 15
# Credit Approval
# Japanese Credit Screening
#
# Multivariate, Domain-Theory
# Classification
# Categorical, Real, Integer
# 125
#
# 1992
# Japanese Credit Screening
# Computer Hardware
#
# Multivariate
# Regression
# Integer
# 209
# 9
# 1987
# Computer Hardware
# Contraceptive Method Choice
#
# Multivariate
# Classification
# Categorical, Integer
# 1473
# 9
# 1997
# Contraceptive Method Choice
# Covertype
#
# Multivariate
# Classification
# Categorical, Integer
# 581012
# 54
# 1998
# Covertype
# Cylinder Bands
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 512
# 39
# 1995
# Cylinder Bands
# Dermatology
#
# Multivariate
# Classification
# Categorical, Integer
# 366
# 33
# 1998
# Dermatology
# Diabetes
#
# Multivariate, Time-Series
#
# Categorical, Integer
#
# 20
# Diabetes
# DGP2 - The Second Data Generation Program
#
# Data-Generator
#
# Real
# DGP2 - The Second Data Generation Program
# Document Understanding
#
#
#
#
#
#
# 1994
# Document Understanding
# EBL Domain Theories
# EBL Domain Theories
# Echocardiogram
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 132
# 12
# 1989
# Echocardiogram
# Ecoli
#
# Multivariate
# Classification
# Real
# 336
# 8
# 1996
# Ecoli
# Flags
#
# Multivariate
# Classification
# Categorical, Integer
# 194
# 30
# 1990
# Flags
# Function Finding
#
#
# Function-Learning
# Real
# 352
#
# 1990
# Function Finding
# Glass Identification
#
# Multivariate
# Classification
# Real
# 214
# 10
# 1987
# Glass Identification
# Haberman's Survival
#
# Multivariate
# Classification
# Integer
# 306
# 3
# 1999
# Haberman's Survival
# Hayes-Roth
#
# Multivariate
# Classification
# Categorical
# 160
# 5
# 1989
# Hayes-Roth
# Heart Disease
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 303
# 75
# 1988
# Heart Disease
# Hepatitis
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 155
# 19
# 1988
# Hepatitis
# Horse Colic
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 368
# 27
# 1989
# Horse Colic
# ICU
#
# Multivariate, Time-Series
#
# Real
# ICU
# Image Segmentation
#
# Multivariate
# Classification
# Real
# 2310
# 19
# 1990
# Image Segmentation
# Internet Advertisements
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 3279
# 1558
# 1998
# Internet Advertisements
# Ionosphere
#
# Multivariate
# Classification
# Integer, Real
# 351
# 34
# 1989
# Ionosphere
# Iris
#
# Multivariate
# Classification
# Real
# 150
# 4
# 1988
# Iris
# ISOLET
#
# Multivariate
# Classification
# Real
# 7797
# 617
# 1994
# ISOLET
# Kinship
#
# Relational
# Relational-Learning
# Categorical
# 104
# 12
# 1990
# Kinship
# Labor Relations
#
# Multivariate
#
# Categorical, Integer, Real
# 57
# 16
# 1988
# Labor Relations
# LED Display Domain
#
# Multivariate, Data-Generator
# Classification
# Categorical
#
# 7
# 1988
# LED Display Domain
# Lenses
#
# Multivariate
# Classification
# Categorical
# 24
# 4
# 1990
# Lenses
# Letter Recognition
#
# Multivariate
# Classification
# Integer
# 20000
# 16
# 1991
# Letter Recognition
# Liver Disorders
#
# Multivariate
#
# Categorical, Integer, Real
# 345
# 7
# 1990
# Liver Disorders
# Logic Theorist
#
# Domain-Theory
# Logic Theorist
# Lung Cancer
#
# Multivariate
# Classification
# Integer
# 32
# 56
# 1992
# Lung Cancer
# Lymphography
#
# Multivariate
# Classification
# Categorical
# 148
# 18
# 1988
# Lymphography
# Mechanical Analysis
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 209
# 8
# 1990
# Mechanical Analysis
# Meta-data
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 528
# 22
# 1996
# Meta-data
# Mobile Robots
#
# Domain-Theory
#
# Categorical, Integer, Real
#
#
# 1995
# Mobile Robots
# Molecular Biology (Promoter Gene Sequences)
#
# Sequential, Domain-Theory
# Classification
# Categorical
# 106
# 58
# 1990
# Molecular Biology (Promoter Gene Sequences)
# Molecular Biology (Protein Secondary Structure)
#
# Sequential
# Classification
# Categorical
# 128
# Molecular Biology (Protein Secondary Structure)
# Molecular Biology (Splice-junction Gene Sequences)
#
# Sequential, Domain-Theory
# Classification
# Categorical
# 3190
# 61
# 1992
# Molecular Biology (Splice-junction Gene Sequences)
# MONK's Problems
#
# Multivariate
# Classification
# Categorical
# 432
# 7
# 1992
# MONK's Problems
# Moral Reasoner
#
# Domain-Theory
#
#
# 202
#
# 1994
# Moral Reasoner
# Multiple Features
#
# Multivariate
# Classification
# Integer, Real
# 2000
# 649
# Multiple Features
# Mushroom
#
# Multivariate
# Classification
# Categorical
# 8124
# 22
# 1987
# Mushroom
# Musk (Version 1)
#
# Multivariate
# Classification
# Integer
# 476
# 168
# 1994
# Musk (Version 1)
# Musk (Version 2)
#
# Multivariate
# Classification
# Integer
# 6598
# 168
# 1994
# Musk (Version 2)
# Nursery
#
# Multivariate
# Classification
# Categorical
# 12960
# 8
# 1997
# Nursery
# Othello Domain Theory
#
# Domain-Theory
#
#
#
#
# 1991
# Othello Domain Theory
# Page Blocks Classification
#
# Multivariate
# Classification
# Integer, Real
# 5473
# 10
# 1995
# Page Blocks Classification
# Optical Recognition of Handwritten Digits
#
# Multivariate
# Classification
# Integer
# 5620
# 64
# 1998
# Optical Recognition of Handwritten Digits
# Pen-Based Recognition of Handwritten Digits
#
# Multivariate
# Classification
# Integer
# 10992
# 16
# 1998
# Pen-Based Recognition of Handwritten Digits
# Post-Operative Patient
#
# Multivariate
# Classification
# Categorical, Integer
# 90
# 8
# 1993
# Post-Operative Patient
# Primary Tumor
#
# Multivariate
# Classification
# Categorical
# 339
# 17
# 1988
# Primary Tumor
# Prodigy
#
# Domain-Theory
# Prodigy
# Qualitative Structure Activity Relationships
#
# Domain-Theory
# Qualitative Structure Activity Relationships
# Quadruped Mammals
#
# Multivariate, Data-Generator
# Classification
# Real
#
# 72
# 1992
# Quadruped Mammals
# Servo
#
# Multivariate
# Regression
# Categorical, Integer
# 167
# 4
# 1993
# Servo
# Shuttle Landing Control
#
# Multivariate
# Classification
# Categorical
# 15
# 6
# 1988
# Shuttle Landing Control
# Solar Flare
#
# Multivariate
# Regression
# Categorical
# 1389
# 10
# 1989
# Solar Flare
# Soybean (Large)
#
# Multivariate
# Classification
# Categorical
# 307
# 35
# 1988
# Soybean (Large)
# Soybean (Small)
#
# Multivariate
# Classification
# Categorical
# 47
# 35
# 1987
# Soybean (Small)
# Challenger USA Space Shuttle O-Ring
#
# Multivariate
# Regression
# Integer
# 23
# 4
# 1993
# Challenger USA Space Shuttle O-Ring
# Low Resolution Spectrometer
#
# Multivariate
# Classification
# Integer, Real
# 531
# 102
# 1988
# Low Resolution Spectrometer
# Spambase
#
# Multivariate
# Classification
# Integer, Real
# 4601
# 57
# 1999
# Spambase
# SPECT Heart
#
# Multivariate
# Classification
# Categorical
# 267
# 22
# 2001
# SPECT Heart
# SPECTF Heart
#
# Multivariate
# Classification
# Integer
# 267
# 44
# 2001
# SPECTF Heart
# Sponge
#
# Multivariate
# Clustering
# Categorical, Integer
# 76
# 45
# Sponge
# Statlog Project
#
#
#
#
#
#
# 1992
# Statlog Project
# Student Loan Relational
#
# Domain-Theory
#
#
# 1000
#
# 1993
# Student Loan Relational
# Teaching Assistant Evaluation
#
# Multivariate
# Classification
# Categorical, Integer
# 151
# 5
# 1997
# Teaching Assistant Evaluation
# Tic-Tac-Toe Endgame
#
# Multivariate
# Classification
# Categorical
# 958
# 9
# 1991
# Tic-Tac-Toe Endgame
# Thyroid Disease
#
# Multivariate, Domain-Theory
# Classification
# Categorical, Real
# 7200
# 21
# 1987
# Thyroid Disease
# Trains
#
# Multivariate
# Classification
# Categorical
# 10
# 32
# 1994
# Trains
# University
#
# Multivariate
# Classification
# Categorical, Integer
# 285
# 17
# 1988
# University
# Congressional Voting Records
#
# Multivariate
# Classification
# Categorical
# 435
# 16
# 1987
# Congressional Voting Records
# Water Treatment Plant
#
# Multivariate
# Clustering
# Integer, Real
# 527
# 38
# 1993
# Water Treatment Plant
# Waveform Database Generator (Version 1)
#
# Multivariate, Data-Generator
# Classification
# Real
# 5000
# 21
# 1988
# Waveform Database Generator (Version 1)
# Waveform Database Generator (Version 2)
#
# Multivariate, Data-Generator
# Classification
# Real
# 5000
# 40
# 1988
# Waveform Database Generator (Version 2)
# Wine
#
# Multivariate
# Classification
# Integer, Real
# 178
# 13
# 1991
# Wine
# Yeast
#
# Multivariate
# Classification
# Real
# 1484
# 8
# 1996
# Yeast
# Zoo
#
# Multivariate
# Classification
# Categorical, Integer
# 101
# 17
# 1990
# Zoo
# Undocumented
# Undocumented
# Twenty Newsgroups
#
# Text
#
#
# 20000
#
# 1999
# Twenty Newsgroups
# Australian Sign Language signs
#
# Multivariate, Time-Series
# Classification
# Categorical, Real
# 6650
# 15
# 1999
# Australian Sign Language signs
# Australian Sign Language signs (High Quality)
#
# Multivariate, Time-Series
# Classification
# Real
# 2565
# 22
# 2002
# Australian Sign Language signs (High Quality)
# US Census Data (1990)
#
# Multivariate
# Clustering
# Categorical
# 2458285
# 68
# US Census Data (1990)
# Census-Income (KDD)
#
# Multivariate
# Classification
# Categorical, Integer
# 299285
# 40
# 2000
# Census-Income (KDD)
# Coil 1999 Competition Data
#
# Multivariate
#
# Categorical, Real
# 340
# 17
# 1999
# Coil 1999 Competition Data
# Corel Image Features
#
# Multivariate
#
# Real
# 68040
# 89
# 1999
# Corel Image Features
# E. Coli Genes
#
# Relational
#
#
#
#
# 2001
# E. Coli Genes
# EEG Database
#
# Multivariate, Time-Series
#
# Categorical, Integer, Real
# 122
# 4
# 1999
# EEG Database
# El Nino
#
# Spatio-temporal
#
# Integer, Real
# 178080
# 12
# 1999
# El Nino
# Entree Chicago Recommendation Data
#
# Transactional, Sequential
# Recommender-Systems
# Categorical
# 50672
#
# 2000
# Entree Chicago Recommendation Data
# CMU Face Images
#
# Image
# Classification
# Integer
# 640
#
# 1999
# CMU Face Images
# Insurance Company Benchmark (COIL 2000)
#
# Multivariate
# Regression, Description
# Categorical, Integer
# 9000
# 86
# 2000
# Insurance Company Benchmark (COIL 2000)
# Internet Usage Data
#
# Multivariate
#
# Categorical, Integer
# 10104
# 72
# 1999
# Internet Usage Data
# IPUMS Census Database
#
# Multivariate
#
# Categorical, Integer
# 256932
# 61
# 1999
# IPUMS Census Database
# Japanese Vowels
#
# Multivariate, Time-Series
# Classification
# Real
# 640
# 12
# Japanese Vowels
# KDD Cup 1998 Data
#
# Multivariate
# Regression
# Categorical, Integer
# 191779
# 481
# 1998
# KDD Cup 1998 Data
# KDD Cup 1999 Data
#
# Multivariate
# Classification
# Categorical, Integer
# 4000000
# 42
# 1999
# KDD Cup 1999 Data
# M. Tuberculosis Genes
#
# Relational
#
#
#
#
# 2001
# M. Tuberculosis Genes
# Movie
#
# Multivariate, Relational
#
#
# 10000
#
# 1999
# Movie
# MSNBC.com Anonymous Web Data
#
# Sequential
#
# Categorical
# 989818
# MSNBC.com Anonymous Web Data
# NSF Research Award Abstracts 1990-2003
#
# Text
#
#
# 129000
#
# 2003
# NSF Research Award Abstracts 1990-2003
# Pioneer-1 Mobile Robot Data
#
# Multivariate, Time-Series
#
# Categorical, Real
#
#
# 1999
# Pioneer-1 Mobile Robot Data
# Pseudo Periodic Synthetic Time Series
#
# Univariate, Time-Series
#
#
# 100000
#
# 1999
# Pseudo Periodic Synthetic Time Series
# Reuters-21578 Text Categorization Collection
#
# Text
# Classification
# Categorical
# 21578
# 5
# 1997
# Reuters-21578 Text Categorization Collection
# Robot Execution Failures
#
# Multivariate, Time-Series
# Classification
# Integer
# 463
# 90
# 1999
# Robot Execution Failures
# Synthetic Control Chart Time Series
#
# Time-Series
# Classification, Clustering
# Real
# 600
#
# 1999
# Synthetic Control Chart Time Series
# Syskill and Webert Web Page Ratings
#
# Multivariate, Text
# Classification
# Categorical
# 332
# 5
# 1998
# Syskill and Webert Web Page Ratings
# UNIX User Data
#
# Text, Sequential
# UNIX User Data
# Volcanoes on Venus - JARtool experiment
#
# Image
# Classification
# Volcanoes on Venus - JARtool experiment
# Statlog (Australian Credit Approval)
#
# Multivariate
# Classification
# Categorical, Integer, Real
# 690
# 14
# Statlog (Australian Credit Approval)
# Statlog (German Credit Data)
#
# Multivariate
# Classification
# Categorical, Integer
# 1000
# 20
# 1994
# Statlog (German Credit Data)
# Statlog (Heart)
#
# Multivariate
# Classification
# Categorical, Real
# 270
# 13
# Statlog (Heart)
# Statlog (Landsat Satellite)
#
# Multivariate
# Classification
# Integer
# 6435
# 36
# 1993
# Statlog (Landsat Satellite)
# Statlog (Image Segmentation)
#
# Multivariate
# Classification
# Real
# 2310
# 19
# 1990
# Statlog (Image Segmentation)
# Statlog (Shuttle)
#
# Multivariate
# Classification
# Integer
# 58000
# 9
# Statlog (Shuttle)
# Statlog (Vehicle Silhouettes)
#
# Multivariate
# Classification
# Integer
# 946
# 18
# Statlog (Vehicle Silhouettes)
# Connectionist Bench (Nettalk Corpus)
#
# Multivariate
#
# Categorical
# 20008
# 4
# Connectionist Bench (Nettalk Corpus)
# Connectionist Bench (Sonar, Mines vs. Rocks)
#
# Multivariate
# Classification
# Real
# 208
# 60
# Connectionist Bench (Sonar, Mines vs. Rocks)
# Connectionist Bench (Vowel Recognition - Deterding Data)
#
#
# Classification
# Real
# 528
# 10
# Connectionist Bench (Vowel Recognition - Deterding Data)
# Economic Sanctions
#
# Domain-Theory
# Economic Sanctions
# Protein Data
# Protein Data
# Cloud
#
# Multivariate
#
# Real
# 1024
# 10
# 1989
# Cloud
# CalIt2 Building People Counts
#
# Multivariate, Time-Series
#
# Categorical, Integer
# 10080
# 4
# 2006
# CalIt2 Building People Counts
# Dodgers Loop Sensor
#
# Multivariate, Time-Series
#
# Categorical, Integer
# 50400
# 3
# 2006
# Dodgers Loop Sensor
# Poker Hand
#
# Multivariate
# Classification
# Categorical, Integer
# 1025010
# 11
# 2007
# Poker Hand
# MAGIC Gamma Telescope
#
# Multivariate
# Classification
# Real
# 19020
# 11
# 2007
# MAGIC Gamma Telescope
# UJI Pen Characters
#
# Multivariate, Sequential
# Classification
# Integer
# 1364
#
# 2007
# UJI Pen Characters
# Mammographic Mass
#
# Multivariate
# Classification
# Integer
# 961
# 6
# 2007
# Mammographic Mass
# Forest Fires
#
# Multivariate
# Regression
# Real
# 517
# 13
# 2008
# Forest Fires
# Reuters Transcribed Subset
#
# Text
# Classification
#
# 200
#
# 2008
# Reuters Transcribed Subset
# Bag of Words
#
# Text
# Clustering
# Integer
# 8000000
# 100000
# 2008
# Bag of Words
# Concrete Compressive Strength
#
# Multivariate
# Regression
# Real
# 1030
# 9
# 2007
# Concrete Compressive Strength
# Hill-Valley
#
# Sequential
# Classification
# Real
# 606
# 101
# 2008
# Hill-Valley
# Arcene
#
# Multivariate
# Classification
# Real
# 900
# 10000
# 2008
# Arcene
# Dexter
#
# Multivariate
# Classification
# Integer
# 2600
# 20000
# 2008
# Dexter
# Dorothea
#
# Multivariate
# Classification
# Integer
# 1950
# 100000
# 2008
# Dorothea
# Gisette
#
# Multivariate
# Classification
# Integer
# 13500
# 5000
# 2008
# Gisette
# Madelon
#
# Multivariate
# Classification
# Real
# 4400
# 500
# 2008
# Madelon
# Ozone Level Detection
#
# Multivariate, Sequential, Time-Series
# Classification
# Real
# 2536
# 73
# 2008
# Ozone Level Detection
# Abscisic Acid Signaling Network
#
# Multivariate
# Causal-Discovery
# Integer
# 300
# 43
# 2008
# Abscisic Acid Signaling Network
# Parkinsons
#
# Multivariate
# Classification
# Real
# 197
# 23
# 2008
# Parkinsons
# Character Trajectories
#
# Time-Series
# Classification, Clustering
# Real
# 2858
# 3
# 2008
# Character Trajectories
# Blood Transfusion Service Center
#
# Multivariate
# Classification
# Real
# 748
# 5
# 2008
# Blood Transfusion Service Center
# UJI Pen Characters (Version 2)
#
# Multivariate, Sequential
# Classification
# Integer
# 11640
#
# 2009
# UJI Pen Characters (Version 2)
# Semeion Handwritten Digit
#
# Multivariate
# Classification
# Integer
# 1593
# 256
# 2008
# Semeion Handwritten Digit
# SECOM
#
# Multivariate
# Classification, Causal-Discovery
# Real
# 1567
# 591
# 2008
# SECOM
# Plants
#
# Multivariate
# Clustering
# Categorical
# 22632
# 70
# 2008
# Plants
# Libras Movement
#
# Multivariate, Sequential
# Classification, Clustering
# Real
# 360
# 91
# 2009
# Libras Movement
# Concrete Slump Test
#
# Multivariate
# Regression
# Real
# 103
# 10
# 2009
# Concrete Slump Test
# Communities and Crime
#
# Multivariate
# Regression
# Real
# 1994
# 128
# 2009
# Communities and Crime
# Acute Inflammations
#
# Multivariate
# Classification
# Categorical, Integer
# 120
# 6
# 2009
# Acute Inflammations
# Wine Quality
#
# Multivariate
# Classification, Regression
# Real
# 4898
# 12
# 2009
# Wine Quality
# URL Reputation
#
# Multivariate, Time-Series
# Classification
# Integer, Real
# 2396130
# 3231961
# 2009
# URL Reputation
# p53 Mutants
#
# Multivariate
# Classification
# Real
# 16772
# 5409
# 2010
# p53 Mutants
# Parkinsons Telemonitoring
#
# Multivariate
# Regression
# Integer, Real
# 5875
# 26
# 2009
# Parkinsons Telemonitoring
# Demospongiae
#
# Multivariate
# Classification
# Integer
# 503
#
# 2010
# Demospongiae
# Opinosis Opinion ⁄ Review
#
# Text
#
#
# 51
#
# 2010
# Opinosis Opinion ⁄ Review
# Breast Tissue
#
# Multivariate
# Classification
# Real
# 106
# 10
# 2010
# Breast Tissue
# Cardiotocography
#
# Multivariate
# Classification
# Real
# 2126
# 23
# 2010
# Cardiotocography
# Wall-Following Robot Navigation Data
#
# Multivariate, Sequential
# Classification
# Real
# 5456
# 24
# 2010
# Wall-Following Robot Navigation Data
# Spoken Arabic Digit
#
# Multivariate, Time-Series
# Classification
# Real
# 8800
# 13
# 2010
# Spoken Arabic Digit
# Localization Data for Person Activity
#
# Univariate, Sequential, Time-Series
# Classification
# Real
# 164860
# 8
# 2010
# Localization Data for Person Activity
# AutoUniv
#
# Multivariate
# Classification
# Categorical, Integer, Real
#
#
# 2010
# AutoUniv
# Steel Plates Faults
#
# Multivariate
# Classification
# Integer, Real
# 1941
# 27
# 2010
# Steel Plates Faults
# MiniBooNE particle identification
#
# Multivariate
# Classification
# Real
# 130065
# 50
# 2010
# MiniBooNE particle identification
# YearPredictionMSD
#
# Multivariate
# Regression
# Real
# 515345
# 90
# 2011
# YearPredictionMSD
# PEMS-SF
#
# Multivariate, Time-Series
# Classification
# Real
# 440
# 138672
# 2011
# PEMS-SF
# OpinRank Review Dataset
#
# Text
#
#
#
#
# 2011
# OpinRank Review Dataset
# Relative location of CT slices on axial axis
#
# Domain-Theory
# Regression
# Real
# 53500
# 386
# 2011
# Relative location of CT slices on axial axis
# Online Handwritten Assamese Characters Dataset
#
# Multivariate, Sequential
# Classification
# Integer
# 8235
#
# 2011
# Online Handwritten Assamese Characters Dataset
# PubChem Bioassay Data
#
# Multivariate
# Classification
# Integer, Real
#
#
# 2011
# PubChem Bioassay Data
# Record Linkage Comparison Patterns
#
# Multivariate
# Classification
# Real
# 5749132
# 12
# 2011
# Record Linkage Comparison Patterns
# Communities and Crime Unnormalized
#
# Multivariate
# Regression
# Real
# 2215
# 147
# 2011
# Communities and Crime Unnormalized
# Vertebral Column
#
# Multivariate
# Classification
# Real
# 310
# 6
# 2011
# Vertebral Column
# EMG Physical Action Data Set
#
# Time-Series
# Classification
# Real
# 10000
# 8
# 2011
# EMG Physical Action Data Set
# Vicon Physical Action Data Set
#
# Time-Series
# Classification
# Real
# 3000
# 27
# 2011
# Vicon Physical Action Data Set
# Amazon Commerce reviews set
#
# Multivariate, Text, Domain-Theory
# Classification
# Real
# 1500
# 10000
# 2011
# Amazon Commerce reviews set
# Amazon Access Samples
#
# Time-Series, Domain-Theory
# Regression, Clustering, Causal-Discovery
#
# 30000
# 20000
# 2011
# Amazon Access Samples
# Reuter_50_50
#
# Multivariate, Text, Domain-Theory
# Classification, Clustering
# Real
# 2500
# 10000
# 2011
# Reuter_50_50
# Farm Ads
#
# Text
# Classification
#
# 4143
# 54877
# 2011
# Farm Ads
# DBWorld e-mails
#
# Text
# Classification
#
# 64
# 4702
# 2011
# DBWorld e-mails
# KEGG Metabolic Relation Network (Directed)
#
# Multivariate, Univariate, Text
# Classification, Regression, Clustering
# Integer, Real
# 53414
# 24
# 2011
# KEGG Metabolic Relation Network (Directed)
# KEGG Metabolic Reaction Network (Undirected)
#
# Multivariate, Univariate, Text
# Classification, Regression, Clustering
# Integer, Real
# 65554
# 29
# 2011
# KEGG Metabolic Reaction Network (Undirected)
# Bank Marketing
#
# Multivariate
# Classification
# Real
# 45211
# 17
# 2012
# Bank Marketing
# YouTube Comedy Slam Preference Data
#
# Text
# Classification
#
# 1138562
# 3
# 2012
# YouTube Comedy Slam Preference Data
# Gas Sensor Array Drift Dataset
#
# Multivariate
# Classification
# Real
# 13910
# 128
# 2012
# Gas Sensor Array Drift Dataset
# ILPD (Indian Liver Patient Dataset)
#
# Multivariate
# Classification
# Integer, Real
# 583
# 10
# 2012
# ILPD (Indian Liver Patient Dataset)
# OPPORTUNITY Activity Recognition
#
# Multivariate, Time-Series
# Classification
# Real
# 2551
# 242
# 2012
# OPPORTUNITY Activity Recognition
# Nomao
#
# Univariate
# Classification
# Real
# 34465
# 120
# 2012
# Nomao
# SMS Spam Collection
#
# Multivariate, Text, Domain-Theory
# Classification, Clustering
# Real
# 5574
#
# 2012
# SMS Spam Collection
# Skin Segmentation
#
# Univariate
# Classification
# Real
# 245057
# 4
# 2012
# Skin Segmentation
# Planning Relax
#
# Univariate
# Classification
# Real
# 182
# 13
# 2012
# Planning Relax
# PAMAP2 Physical Activity Monitoring
#
# Multivariate, Time-Series
# Classification
# Real
# 3850505
# 52
# 2012
# PAMAP2 Physical Activity Monitoring
# Restaurant & consumer data
#
# Multivariate
#
#
# 138
# 47
# 2012
# Restaurant & consumer data
# CNAE-9
#
# Multivariate, Text
# Classification
# Integer
# 1080
# 857
# 2012
# CNAE-9
# Individual household electric power consumption
#
# Multivariate, Time-Series
# Regression, Clustering
# Real
# 2075259
# 9
# 2012
# Individual household electric power consumption
# seeds
#
# Multivariate
# Classification, Clustering
# Real
# 210
# 7
# 2012
# seeds
# Northix
#
# Multivariate, Univariate, Text
# Classification
# Integer, Real
# 115
# 200
# 2012
# Northix
# QtyT40I10D100K
#
# Sequential
#
# Integer
# 3960456
# 4
# 2012
# QtyT40I10D100K
# Legal Case Reports
#
# Text
# Classification
#
#
#
# 2012
# Legal Case Reports
# Human Activity Recognition Using Smartphones
#
# Multivariate, Time-Series
# Classification, Clustering
#
# 10299
# 561
# 2012
# Human Activity Recognition Using Smartphones
# One-hundred plant species leaves data set
#
#
# Classification
# Real
# 1600
# 64
# 2012
# One-hundred plant species leaves data set
# Energy efficiency
#
# Multivariate
# Classification, Regression
# Integer, Real
# 768
# 8
# 2012
# Energy efficiency
# Yacht Hydrodynamics
#
# Multivariate
# Regression
# Real
# 308
# 7
# 2013
# Yacht Hydrodynamics
# Fertility
#
# Multivariate
# Classification, Regression
# Real
# 100
# 10
# 2013
# Fertility
# Daphnet Freezing of Gait
#
# Multivariate, Time-Series
# Classification
# Real
# 237
# 9
# 2013
# Daphnet Freezing of Gait
# 3D Road Network (North Jutland, Denmark)
#
# Sequential, Text
# Regression, Clustering
# Real
# 434874
# 4
# 2013
# 3D Road Network (North Jutland, Denmark)
# ISTANBUL STOCK EXCHANGE
#
# Multivariate, Univariate, Time-Series
# Classification, Regression
# Real
# 536
# 8
# 2013
# ISTANBUL STOCK EXCHANGE
# Buzz in social media
#
# Time-Series, Multivariate
# Regression, Classification
# Integer, Real
# 140000
# 77
# 2013
# Buzz in social media
# First-order theorem proving
#
# Multivariate
# Classification
# Real
# 6118
# 51
# 2013
# First-order theorem proving
# Wearable Computing: Classification of Body Postures and Movements (PUC-Rio)
#
# Sequential
# Classification
# Integer, Real
# 165632
# 18
# 2013
# Wearable Computing: Classification of Body Postures and Movements (PUC-Rio)
# Gas sensor arrays in open sampling settings
#
# Multivariate, Time-Series
# Classification
# Real
# 18000
# 1950000
# 2013
# Gas sensor arrays in open sampling settings
# Climate Model Simulation Crashes
#
# Multivariate
# Classification
# Real
# 540
# 18
# 2013
# Climate Model Simulation Crashes
# MicroMass
#
# Multivariate
# Classification
# Real
# 931
# 1300
# 2013
# MicroMass
# QSAR biodegradation
#
# Multivariate
# Classification
# Integer, Real
# 1055
# 41
# 2013
# QSAR biodegradation
# BLOGGER
#
# Multivariate
# Classification
#
# 100
# 6
# 2013
# BLOGGER
# Daily and Sports Activities
#
# Multivariate, Time-Series
# Classification, Clustering
# Real
# 9120
# 5625
# 2013
# Daily and Sports Activities
# User Knowledge Modeling
#
# Multivariate
# Classification, Clustering
# Integer
# 403
# 5
# 2013
# User Knowledge Modeling
# Reuters RCV1 RCV2 Multilingual, Multiview Text Categorization Test collection
#
# Multivariate
# Classification
# Real
# 111740
#
# 2013
# Reuters RCV1 RCV2 Multilingual, Multiview Text Categorization Test collection
# NYSK
#
# Multivariate, Sequential, Text
# Clustering
#
# 10421
# 7
# 2013
# NYSK
# Turkiye Student Evaluation
#
# Multivariate
# Classification, Clustering
#
# 5820
# 33
# 2013
# Turkiye Student Evaluation
# ser Knowledge Modeling Data (Students' Knowledge Levels on DC Electrical Machines)
#
# Multivariate
# Classification
# Real
# 403
# 5
# 2013
# ser Knowledge Modeling Data (Students' Knowledge Levels on DC Electrical Machines)
# EEG Eye State
#
# Multivariate, Sequential, Time-Series
# Classification
# Integer, Real
# 14980
# 15
# 2013
# EEG Eye State
# Physicochemical Properties of Protein Tertiary Structure
#
# Multivariate
# Regression
# Real
# 45730
# 9
# 2013
# Physicochemical Properties of Protein Tertiary Structure
# seismic-bumps
#
# Multivariate
# Classification
# Real
# 2584
# 19
# 2013
# seismic-bumps
# banknote authentication
#
# Multivariate
# Classification
# Real
# 1372
# 5
# 2013
# banknote authentication
# USPTO Algorithm Challenge, run by NASA-Harvard Tournament Lab and TopCoder    Problem: Pat
#
# Domain-Theory
# Classification
# Integer
# 306
# 5
# 2013
# USPTO Algorithm Challenge, run by NASA-Harvard Tournament Lab and TopCoder    Problem: Pat
# YouTube Multiview Video Games Dataset
#
# Multivariate, Text
# Classification, Clustering
# Integer, Real
# 120000
# 1000000
# 2013
# YouTube Multiview Video Games Dataset
# Gas Sensor Array Drift Dataset at Different Concentrations
#
# Multivariate, Time-Series
# Classification, Regression, Clustering, Causa
# Real
# 13910
# 129
# 2013
# Gas Sensor Array Drift Dataset at Different Concentrations
# Activities of Daily Living (ADLs) Recognition Using Binary Sensors
#
# Multivariate, Sequential, Time-Series
# Classification, Clustering
#
# 2747
#
# 2013
# Activities of Daily Living (ADLs) Recognition Using Binary Sensors
# SkillCraft1 Master Table Dataset
#
# Multivariate
# Regression
# Integer, Real
# 3395
# 20
# 2013
# SkillCraft1 Master Table Dataset
# Weight Lifting Exercises monitored with Inertial Measurement Units
#
# Multivariate
# Classification
# Real
# 39242
# 152
# 2013
# Weight Lifting Exercises monitored with Inertial Measurement Units
# SML2010
#
# Multivariate, Sequential, Time-Series, Text
# Regression
# Real
# 4137
# 24
# 2014
# SML2010
# Bike Sharing Dataset
#
# Univariate
# Regression
# Integer, Real
# 17389
# 16
# 2013
# Bike Sharing Dataset
# Predict keywords activities in a online social media
#
# Multivariate, Sequential, Time-Series
#
# Integer, Real
# 51
# 35
# 2013
# Predict keywords activities in a online social media
# Thoracic Surgery Data
#
# Multivariate
# Classification
# Integer, Real
# 470
# 17
# 2013
# Thoracic Surgery Data
# EMG dataset in Lower Limb
#
# Multivariate, Time-Series
#
# Real
# 132
# 5
# 2014
# EMG dataset in Lower Limb
# SUSY
#
#
# Classification
# Real
# 5000000
# 18
# 2014
# SUSY
# HIGGS
#
#
# Classification
# Real
# 11000000
# 28
# 2014
# HIGGS
# Qualitative_Bankruptcy
#
# Multivariate
# Classification
#
# 250
# 7
# 2014
# Qualitative_Bankruptcy
# LSVT Voice Rehabilitation
#
# Multivariate
# Classification
# Real
# 126
# 309
# 2014
# LSVT Voice Rehabilitation
# Dataset for ADL Recognition with Wrist-worn Accelerometer
#
# Multivariate, Time-Series
# Classification, Clustering
#
#
# 3
# 2014
# Dataset for ADL Recognition with Wrist-worn Accelerometer
# Wilt
#
# Multivariate
# Classification
#
# 4889
# 6
# 2014
# Wilt
# User Identification From Walking Activity
#
# Univariate, Sequential, Time-Series
# Classification, Clustering
# Real
#
#
# 2014
# User Identification From Walking Activity
# Activity Recognition from Single Chest-Mounted Accelerometer
#
# Univariate, Sequential, Time-Series
# Classification, Clustering
# Real
#
#
# 2014
# Activity Recognition from Single Chest-Mounted Accelerometer
# Leaf
#
# Multivariate
# Classification
# Real
# 340
# 16
# 2014
# Leaf
# Dresses_Attribute_Sales
#
# Text
# Classification, Clustering
#
# 501
# 13
# 2014
# Dresses_Attribute_Sales
# Tamilnadu Electricity Board Hourly Readings
#
# Multivariate
# Classification, Regression, Clustering
# Real
# 45781
# 5
# 2013
# Tamilnadu Electricity Board Hourly Readings
# Airfoil Self-Noise
#
# Multivariate
# Regression
# Real
# 1503
# 6
# 2014
# Airfoil Self-Noise
# Wholesale customers
#
# Multivariate
# Classification, Clustering
# Integer
# 440
# 8
# 2014
# Wholesale customers
# Twitter Data set for Arabic Sentiment Analysis
#
# Text
# Classification
#
# 2000
# 2
# 2014
# Twitter Data set for Arabic Sentiment Analysis
# Combined Cycle Power Plant
#
# Multivariate
# Regression
# Real
# 9568
# 4
# 2014
# Combined Cycle Power Plant
# Urban Land Cover
#
# Multivariate
# Classification
#
# 168
# 148
# 2014
# Urban Land Cover
# Diabetes 130-US hospitals for years 1999-2008
#
# Multivariate
# Classification, Clustering
# Integer
# 100000
# 55
# 2014
# Diabetes 130-US hospitals for years 1999-2008
# Bach Choral Harmony
#
# Sequential
# Classification
#
# 5665
# 17
# 2014
# Bach Choral Harmony
# StoneFlakes
#
# Multivariate
# Classification, Clustering, Causal-Discovery
# Real
# 79
# 8
# 2014
# StoneFlakes
# Tennis Major Tournament Match Statistics
#
# Multivariate
# Classification, Regression, Clustering
# Integer, Real
# 127
# 42
# 2014
# Tennis Major Tournament Match Statistics
# Parkinson Speech Dataset with  Multiple Types of Sound Recordings
#
# Multivariate
# Classification, Regression
# Integer, Real
# 1040
# 26
# 2014
# Parkinson Speech Dataset with  Multiple Types of Sound Recordings
# Gesture Phase Segmentation
#
# Multivariate, Sequential, Time-Series
# Classification, Clustering
# Real
# 9900
# 50
# 2014
# Gesture Phase Segmentation
# Perfume Data
#
# Univariate, Domain-Theory
# Classification, Clustering
# Integer
# 560
# 2
# 2014
# Perfume Data
# BlogFeedback
#
# Multivariate
# Regression
# Integer, Real
# 60021
# 281
# 2014
# BlogFeedback
# REALDISP Activity Recognition Dataset
#
# Multivariate, Time-Series
# Classification
# Real
# 1419
# 120
# 2014
# REALDISP Activity Recognition Dataset
# Newspaper and magazine images segmentation dataset
#
#
# Classification
#
# 101
#
# 2014
# Newspaper and magazine images segmentation dataset
# AAAI 2014 Accepted Papers
#
# Multivariate
# Clustering
#
# 399
# 6
# 2014
# AAAI 2014 Accepted Papers
# Gas sensor array under flow modulation
#
# Multivariate, Time-Series
# Classification, Regression
# Real
# 58
# 120432
# 2014
# Gas sensor array under flow modulation
# Gas sensor array exposed to turbulent gas mixtures
#
# Multivariate, Time-Series
# Classification, Regression
# Real
# 180
# 150000
# 2014
# Gas sensor array exposed to turbulent gas mixtures
# UJIIndoorLoc
#
# Multivariate
# Classification, Regression
# Integer, Real
# 21048
# 529
# 2014
# UJIIndoorLoc
# Sentence Classification
#
# Text
# Classification
# Integer
#
#
# 2014
# Sentence Classification
# Dow Jones Index
#
# Time-Series
# Classification, Clustering
# Integer, Real
# 750
# 16
# 2014
# Dow Jones Index
# sEMG for Basic Hand movements
#
# Time-Series
# Classification
# Real
# 3000
# 2500
# 2014
# sEMG for Basic Hand movements
# AAAI 2013 Accepted Papers
#
# Multivariate
# Clustering
#
# 150
# 5
# 2014
# AAAI 2013 Accepted Papers
# Geographical Original of Music
#
# Multivariate
# Classification, Regression
# Real
# 1059
# 68
# 2014
# Geographical Original of Music
# Condition Based Maintenance of Naval Propulsion Plants
#
# Multivariate
# Regression
# Real
# 11934
# 16
# 2014
# Condition Based Maintenance of Naval Propulsion Plants
# Grammatical Facial Expressions
#
# Multivariate, Sequential
# Classification, Clustering
# Real
# 27965
# 100
# 2014
# Grammatical Facial Expressions
# NoisyOffice
#
# Multivariate
# Classification, Regression
# Real
# 216
# 216
# 2015
# NoisyOffice
# MHEALTH Dataset
#
# Multivariate, Time-Series
# Classification
# Real
# 120
# 23
# 2014
# MHEALTH Dataset
# Student Performance
#
# Multivariate
# Classification, Regression
# Integer
# 649
# 33
# 2014
# Student Performance
# ElectricityLoadDiagrams20112014
#
# Time-Series
# Regression, Clustering
# Real
# 370
# 140256
# 2015
# ElectricityLoadDiagrams20112014
# Gas sensor array under dynamic gas mixtures
#
# Multivariate, Time-Series
# Classification, Regression
# Real
# 4178504
# 19
# 2015
# Gas sensor array under dynamic gas mixtures
# microblogPCU
#
# Multivariate, Univariate, Sequential, Text
# Classification, Causal-Discovery
# Integer, Real
# 221579
# 20
# 2015
# microblogPCU
# Firm-Teacher_Clave-Direction_Classification
#
# Multivariate
# Classification
#
# 10800
# 20
# 2015
# Firm-Teacher_Clave-Direction_Classification
# Dataset for Sensorless Drive Diagnosis
#
# Multivariate
# Classification
# Real
# 58509
# 49
# 2015
# Dataset for Sensorless Drive Diagnosis
# TV News Channel Commercial Detection Dataset
#
# Multivariate
# Classification, Clustering
# Real
# 129685
# 12
# 2015
# TV News Channel Commercial Detection Dataset
# Phishing Websites
#
#
# Classification
# Integer
# 2456
# 30
# 2015
# Phishing Websites
# Greenhouse Gas Observing Network
#
# Multivariate, Time-Series
# Regression
# Real
# 2921
# 5232
# 2015
# Greenhouse Gas Observing Network
# Diabetic Retinopathy Debrecen Data Set
#
# Multivariate
# Classification
# Integer, Real
# 1151
# 20
# 2014
# Diabetic Retinopathy Debrecen Data Set
# HIV-1 protease cleavage
#
# Multivariate
# Classification
# Categorical
# 6590
# 1
# 2015
# HIV-1 protease cleavage
# Sentiment Labelled Sentences
#
# Text
# Classification
#
# 3000
#
# 2015
# Sentiment Labelled Sentences
# Online News Popularity
#
# Multivariate
# Classification, Regression
# Integer, Real
# 39797
# 61
# 2015
# Online News Popularity
# Forest type mapping
#
# Multivariate
# Classification
#
# 326
# 27
# 2015
# Forest type mapping
# wiki4HE
#
# Multivariate
# Regression, Clustering, Causal-Discovery
#
# 913
# 53
# 2015
# wiki4HE
# Online Video Characteristics and Transcoding Time Dataset
#
# Multivariate
# Regression
# Integer, Real
# 168286
# 11
# 2015
# Online Video Characteristics and Transcoding Time Dataset
# Chronic_Kidney_Disease
#
# Multivariate
# Classification
# Real
# 400
# 25
# 2015
# Chronic_Kidney_Disease
# Machine Learning based ZZAlpha Ltd. Stock Recommendations 2012-2014
#
# Sequential, Time-Series
# Classification
# Real
# 314080
# 0
# 2015
# Machine Learning based ZZAlpha Ltd. Stock Recommendations 2012-2014
# Folio
#
# Multivariate
# Classification, Clustering
#
# 637
# 20
# 2015
# Folio
# Taxi Service Trajectory - Prediction Challenge, ECML PKDD 2015
#
# Multivariate, Sequential, Time-Series, Domain-Theory
# Clustering, Causal-Discovery
# Real
# 1710671
# 9
# 2015
# Taxi Service Trajectory - Prediction Challenge, ECML PKDD 2015
# Cuff-Less Blood Pressure Estimation
#
# Multivariate
# Classification, Regression
# Real
# 12000
# 3
# 2015
# Cuff-Less Blood Pressure Estimation
# Smartphone-Based Recognition of Human Activities and Postural Transitions
#
# Multivariate, Time-Series
# Classification
# Real
# 10929
# 561
# 2015
# Smartphone-Based Recognition of Human Activities and Postural Transitions
# Mice Protein Expression
#
# Multivariate
# Classification, Clustering
# Real
# 1080
# 82
# 2015
# Mice Protein Expression
# UJIIndoorLoc-Mag
#
# Multivariate, Sequential, Time-Series
# Classification, Regression, Clustering
# Integer, Real
# 40000
# 13
# 2015
# UJIIndoorLoc-Mag
# Heterogeneity Activity Recognition
#
# Multivariate, Time-Series
# Classification, Clustering
# Real
# 43930257
# 16
# 2015
# Heterogeneity Activity Recognition
# Educational Process Mining (EPM): A Learning Analytics Data Set
#
# Multivariate, Sequential, Time-Series
# Classification, Regression, Clustering
# Integer
# 230318
# 13
# 2015
# Educational Process Mining (EPM): A Learning Analytics Data Set
# HEPMASS
#
# Multivariate
# Classification
# Real
# 10500000
# 28
# 2016
# HEPMASS
# Indoor User Movement Prediction from RSS data
#
# Multivariate, Sequential, Time-Series
# Classification
# Real
# 13197
# 4
# 2016
# Indoor User Movement Prediction from RSS data
# Open University Learning Analytics dataset
#
# Multivariate, Sequential, Time-Series
# Classification, Regression, Clustering
# Integer
#
#
# 2015
# Open University Learning Analytics dataset
# default of credit card clients
#
# Multivariate
# Classification
# Integer, Real
# 30000
# 24
# 2016
# default of credit card clients
# Mesothelioma’s disease data set
#
# Multivariate
# Classification
# Real
# 324
# 34
# 2016
# Mesothelioma’s disease data set
# Online Retail
#
# Multivariate, Sequential, Time-Series
# Classification, Clustering
# Integer, Real
# 541909
# 8
# 2015
# Online Retail
# SIFT10M
#
# Multivariate
# Causal-Discovery
# Integer
# 11164866
# 128
# 2016
# SIFT10M
# GPS Trajectories
#
# Multivariate
# Classification, Regression
# Real
# 163
# 15
# 2016
# GPS Trajectories
# Detect Malacious Executable(AntiVirus)
#
# Multivariate
# Classification
# Real
# 373
# 513
# 2016
# Detect Malacious Executable(AntiVirus)
# Occupancy Detection
#
# Multivariate, Time-Series
# Classification
# Real
# 20560
# 7
# 2016
# Occupancy Detection
# Improved Spiral Test Using Digitized Graphics Tablet for Monitoring Parkinson’s Disease
#
# Multivariate
# Classification, Regression, Clustering
# Real
# 40
# 7
# 2016
# Improved Spiral Test Using Digitized Graphics Tablet for Monitoring Parkinson’s Disease
# News Aggregator
#
# Multivariate
# Classification, Clustering
#
# 422937
# 5
# 2016
# News Aggregator
# Air Quality
#
# Multivariate, Time-Series
# Regression
# Real
# 9358
# 15
# 2016
# Air Quality
# Twin gas sensor arrays
#
# Multivariate, Time-Series, Domain-Theory
# Classification, Regression
# Real
# 640
# 480000
# 2016
# Twin gas sensor arrays
# Gas sensors for home activity monitoring
#
# Multivariate, Time-Series
# Classification
# Real
# 919438
# 11
# 2016
# Gas sensors for home activity monitoring
# Facebook Comment Volume Dataset
#
# Multivariate
# Regression
# Integer, Real
# 40949
# 54
# 2016
# Facebook Comment Volume Dataset
# Smartphone Dataset for Human Activity Recognition (HAR) in Ambient Assisted Living (AAL)
#
# Time-Series
# Classification
# Real
# 5744
# 561
# 2016
# Smartphone Dataset for Human Activity Recognition (HAR) in Ambient Assisted Living (AAL)
# Polish companies bankruptcy data
#
# Multivariate
# Classification
# Real
# 10503
# 64
# 2016
# Polish companies bankruptcy data
# Activity Recognition system based on Multisensor data fusion (AReM)
#
# Multivariate, Sequential, Time-Series
# Classification
# Real
# 42240
# 6
# 2016
# Activity Recognition system based on Multisensor data fusion (AReM)
# Dota2 Games Results
#
# Multivariate
# Classification
#
# 102944
# 116
# 2016
# Dota2 Games Results
# Facebook metrics
#
# Multivariate
# Regression
# Integer
# 500
# 19
# 2016
# Facebook metrics
# UbiqLog (smartphone lifelogging)
#
# Multivariate
# Causal-Discovery
#
# 9782222
#
# 2016
# UbiqLog (smartphone lifelogging)
# NIPS Conference Papers 1987-2015
#
# Text
# Clustering
# Integer
# 11463
# 5812
# 2016
# NIPS Conference Papers 1987-2015
# HTRU2
#
# Multivariate
# Classification, Clustering
# Real
# 17898
# 9
# 2017
# HTRU2
# Drug consumption (quantified)
#
# Multivariate
# Classification
# Real
# 1885
# 32
# 2016
# Drug consumption (quantified)
# Appliances energy prediction
#
# Multivariate, Time-Series
# Regression
# Real
# 19735
# 29
# 2017
# Appliances energy prediction
# Miskolc IIS Hybrid IPS
#
# Text
# Classification, Clustering, Causal-Discovery
# Integer
# 1540
# 67
# 2016
# Miskolc IIS Hybrid IPS
# KDC-4007 dataset Collection
#
# Multivariate, Text
# Classification, Regression
# Integer
# 4007
#
# 2017
# KDC-4007 dataset Collection
# Geo-Magnetic field and WLAN dataset for indoor localisation from wristband and smartphone
#
# Multivariate, Sequential, Time-Series
# Classification, Regression, Clustering
# Integer, Real
# 153540
# 25
# 2017
# Geo-Magnetic field and WLAN dataset for indoor localisation from wristband and smartphone
# DrivFace
#
# Multivariate
# Classification, Regression, Clustering
# Real
# 606
# 6400
# 2016
# DrivFace
# Website Phishing
#
# Multivariate
# Classification
# Integer
# 1353
# 10
# 2016
# Website Phishing
# YouTube Spam Collection
#
# Text
# Classification
#
# 1956
# 5
# 2017
# YouTube Spam Collection
# Beijing PM2.5 Data
#
# Multivariate, Time-Series
# Regression
# Integer, Real
# 43824
# 13
# 2017
# Beijing PM2.5 Data
# Cargo 2000 Freight Tracking and Tracing
#
# Multivariate, Sequential
# Classification, Regression
# Integer
# 3942
# 98
# 2016
# Cargo 2000 Freight Tracking and Tracing
# Cervical cancer (Risk Factors)
#
# Multivariate
# Classification
# Integer, Real
# 858
# 36
# 2017
# Cervical cancer (Risk Factors)
# Quality Assessment of Digital Colposcopies
#
# Multivariate
# Classification
# Real
# 287
# 69
# 2017
# Quality Assessment of Digital Colposcopies
# KASANDR
#
# Multivariate
# Causal-Discovery
# Integer
# 17764280
# 2158859
# 2017
# KASANDR
# FMA: A Dataset For Music Analysis
#
# Multivariate, Time-Series
# Classification, Clustering
# Real
# 106574
# 518
# 2017
# FMA: A Dataset For Music Analysis
# Air quality
#
# Multivariate, Time-Series
# Regression
# Real
# 9358
# 15
# 2016
# Air quality
# Epileptic Seizure Recognition
#
# Multivariate, Time-Series
# Classification, Clustering
# Integer, Real
# 11500
# 179
# 2017
# Epileptic Seizure Recognition
# Devanagari Handwritten Character Dataset
#
#
# Classification
# Integer
# 92000
#
# 2016
# Devanagari Handwritten Character Dataset
# Stock portfolio performance
#
# Multivariate
# Regression
# Real
# 315
# 12
# 2016
# Stock portfolio performance
# MoCap Hand Postures
#
# Multivariate
# Classification, Clustering
# Integer, Real
# 78095
# 38
# 2016
# MoCap Hand Postures
# Early biomarkers of Parkinson�s disease based on natural connected speech
#
# Multivariate
# Classification, Regression
# Integer, Real
# 130
# 65
# 2017
# Early biomarkers of Parkinson�s disease based on natural connected speech
# Data for Software Engineering Teamwork Assessment in Education Setting
#
# Sequential, Time-Series
# Classification
# Integer, Real
# 74
# 102
# 2017
# Data for Software Engineering Teamwork Assessment in Education Setting
# PM2.5 Data of Five Chinese Cities
#
# Multivariate, Time-Series
# Regression
# Integer, Real
# 52854
# 86
# 2017
# PM2.5 Data of Five Chinese Cities
# Parkinson Disease Spiral Drawings Using Digitized Graphics Tablet
#
# Multivariate
# Classification, Regression, Clustering
# Integer
# 77
# 7
# 2017
# Parkinson Disease Spiral Drawings Using Digitized Graphics Tablet
# Sales_Transactions_Dataset_Weekly
#
# Multivariate, Time-Series
# Clustering
# Integer, Real
# 811
# 53
# 2017
# Sales_Transactions_Dataset_Weekly
# Las Vegas Strip
#
#
# Classification, Regression
# Integer
# 504
# 20
# 2017
# Las Vegas Strip
# Eco-hotel
#
# Text
#
#
# 401
# 1
# 2017
# Eco-hotel
# MEU-Mobile KSD
#
# Multivariate
# Classification
# Integer, Real
# 2856
# 71
# 2016
# MEU-Mobile KSD
# Crowdsourced Mapping
#
# Multivariate
# Classification
#
# 10546
# 29
# 2016
# Crowdsourced Mapping
# gene expression cancer RNA-Seq
#
# Multivariate
# Classification, Clustering
# Real
# 801
# 20531
# 2016
# gene expression cancer RNA-Seq
# Hybrid Indoor Positioning Dataset from WiFi RSSI, Bluetooth and magnetometer
#
# Multivariate, Sequential, Time-Series
# Classification
# Real
# 1540
# 65
# 2016
# Hybrid Indoor Positioning Dataset from WiFi RSSI, Bluetooth and magnetometer
# chestnut – LARVIC
#
#
# Classification, Clustering
#
# 1451
# 3
# 2017
# chestnut – LARVIC
# Burst Header Packet (BHP) flooding attack on Optical Burst Switching (OBS) Network
#
# Text
# Classification
# Integer
# 1075
# 22
# 2017
# Burst Header Packet (BHP) flooding attack on Optical Burst Switching (OBS) Network
# Motion Capture Hand Postures
#
# Multivariate
# Classification, Clustering
# Real
# 78095
# 38
# 2017
# Motion Capture Hand Postures
# Anuran Calls (MFCCs)
#
# Multivariate
# Classification, Clustering
# Real
# 7195
# 22
# 2017
# Anuran Calls (MFCCs)
# TTC-3600: Benchmark dataset for Turkish text categorization
#
# Text
# Classification, Clustering
# Integer
# 3600
# 4814
# 2017
# TTC-3600: Benchmark dataset for Turkish text categorization
# Gastrointestinal Lesions in Regular Colonoscopy
#
# Multivariate
# Classification
# Real
# 76
# 698
# 2016
# Gastrointestinal Lesions in Regular Colonoscopy
# Daily Demand Forecasting Orders
#
# Time-Series
# Regression
# Integer
# 60
# 13
# 2017
# Daily Demand Forecasting Orders
# Paper Reviews
#
# Text
# Classification, Regression
# Integer
# 405
# 10
# 2017
# Paper Reviews
# extention of Z-Alizadeh sani dataset
#
#
# Classification
# Integer, Real
# 303
# 59
# 2017
# extention of Z-Alizadeh sani dataset
# Z-Alizadeh Sani
#
#
# Classification
# Integer, Real
# 303
# 56
# 2017
# Z-Alizadeh Sani
# Dynamic Features of VirusShare Executables
#
# Multivariate, Time-Series
# Classification, Regression
# Integer
# 107888
# 482
# 2017
# Dynamic Features of VirusShare Executables
# IDA2016Challenge
#
# Multivariate
# Classification
# Integer
# 76000
# 171
# 2017
# IDA2016Challenge
# DSRC Vehicle Communications
#
# Sequential, Text
# Clustering
# Real
# 10000
# 5
# 2017
# DSRC Vehicle Communications
# Mturk User-Perceived Clusters over Images
#
# Multivariate, Text
# Clustering
# Integer
# 180
# 500
# 2016
# Mturk User-Perceived Clusters over Images
# Character Font Images
#
# Multivariate
# Classification
# Integer, Real
# 745000
# 411
# 2016
# Character Font Images
# DeliciousMIL: A Data Set for Multi-Label Multi-Instance Learning with Instance Labels
#
# Text
# Classification
# Integer
# 12234
# 8519
# 2016
# DeliciousMIL: A Data Set for Multi-Label Multi-Instance Learning with Instance Labels
# Autistic Spectrum Disorder Screening Data for Children
#
# Multivariate
# Classification
# Integer
# 292
# 21
# 2017
# Autistic Spectrum Disorder Screening Data for Children
# Autistic Spectrum Disorder Screening Data for Adolescent
#
# Multivariate
# Classification
# Integer
# 104
# 21
# 2017
# Autistic Spectrum Disorder Screening Data for Adolescent
# APS Failure at Scania Trucks
#
# Multivariate
# Classification
# Integer, Real
# 60000
# 171
# 2017
# APS Failure at Scania Trucks
# Wireless Indoor Localization
#
# Multivariate
# Classification
# Real
# 2000
# 7
# 2017
# Wireless Indoor Localization
# HCC Survival
#
# Multivariate
# Classification
# Integer, Real
# 165
# 49
# 2017
# HCC Survival
# CSM (Conventional and Social Media Movies) Dataset 2014 and 2015
#
# Multivariate
# Classification, Regression
# Integer
# 217
# 12
# 2017
# CSM (Conventional and Social Media Movies) Dataset 2014 and 2015
# University of Tehran Question Dataset 2016 (UTQD.2016)
#
# Text
# Classification
#
# 1175
# 3
# 2017
# University of Tehran Question Dataset 2016 (UTQD.2016)
# Autism Screening Adult
#
#
# Classification
# Integer
# 704
# 21
# 2017
# Autism Screening Adult
# Activity recognition with healthy older people using a batteryless wearable sensor
#
# Sequential
# Classification
# Real
# 75128
# 9
# 2016
# Activity recognition with healthy older people using a batteryless wearable sensor
# Immunotherapy Dataset
#
# Univariate
# Classification
# Integer, Real
# 90
# 8
# 2018
# Immunotherapy Dataset
# Cryotherapy Dataset
#
# Univariate
# Classification
# Integer, Real
# 90
# 7
# 2018
# Cryotherapy Dataset
# OCT data & Color Fundus Images of Left & Right Eyes
#
# Multivariate
# Classification
# Real
# 50
# 2
# 2016
# OCT data & Color Fundus Images of Left & Right Eyes
# Discrete Tone Image Dataset
#
# Multivariate
# Classification
#
# 71
# 11
# 2018
# Discrete Tone Image Dataset
# News Popularity in Multiple Social Media Platforms
#
# Multivariate, Time-Series, Text
# Regression
# Integer, Real
# 93239
# 11
# 2018
# News Popularity in Multiple Social Media Platforms
# Ultrasonic flowmeter diagnostics
#
# Multivariate
# Classification
# Real
# 540
# 173
# 2018
# Ultrasonic flowmeter diagnostics
# ICMLA 2014 Accepted Papers Data Set
#
# Multivariate
# Classification, Clustering
#
# 105
# 5
# 2018
# ICMLA 2014 Accepted Papers Data Set
# BLE RSSI Dataset for Indoor localization and Navigation
#
# Multivariate, Sequential, Time-Series
# Classification, Clustering
# Integer
# 6611
# 15
# 2018
# BLE RSSI Dataset for Indoor localization and Navigation
# Container Crane Controller Data Set
#
# Univariate, Domain-Theory
# Classification, Regression
# Real
# 15
# 3
# 2018
# Container Crane Controller Data Set
# Residential Building Data Set
#
# Multivariate
# Regression
# Real
# 372
# 105
# 2018
# Residential Building Data Set
# Health News in Twitter
#
# Text
# Clustering
# Real
# 58000
# 25000
# 2018
# Health News in Twitter
# chipseq
#
# Sequential
# Classification
# Integer
# 4960
#
# 2018
# chipseq
# SGEMM GPU kernel performance
#
# Multivariate
# Regression
# Integer
# 241600
# 18
# 2018
# SGEMM GPU kernel performance
# Repeat Consumption Matrices
#
# Multivariate
# Clustering
# Real
# 130000
# 21000
# 2018
# Repeat Consumption Matrices
# detection_of_IoT_botnet_attacks_N_BaIoT
#
# Multivariate, Sequential
# Classification, Clustering
# Real
# 7062606
# 115
# 2018
# ...
# 2.4 GHZ Indoor Channel Measurements
#
# Multivariate
# Classification
# Real
# 7840
# 5
# 2018
# 2.4 GHZ Indoor Channel Measurements
# EMG data for gestures
#
# Time-Series
# Classification
# Real
# 30000
# 6
# 2019
# EMG data for gestures
# Parking Birmingham
#
# Multivariate, Univariate, Sequential, Time-Series
# Classification, Regression, Clustering
# Real
# 35717
# 4
# 2019
# Parking Birmingham
# Behavior of the urban traffic of the city of Sao Paulo in Brazil
#
# Multivariate, Time-Series
# Classification, Regression
# Integer, Real
# 135
# 18
# 2018
# Behavior of the urban traffic of the city of Sao Paulo in Brazil
# Travel Reviews
#
# Multivariate, Text
# Classification, Clustering
# Real
# 980
# 11
# 2018
# Travel Reviews
# Tarvel Review Ratings
#
# Multivariate, Text
# Classification, Clustering
# Real
# 5456
# 25
# 2018
# Tarvel Review Ratings
# Rice Leaf Diseases
#
# Multivariate
# Classification
# Integer
# 120
#
# 2019
# Rice Leaf Diseases
# Gas sensor array temperature modulation
#
# Multivariate, Time-Series
# Classification, Regression
# Real
# 4095000
# 20
# 2019
# Gas sensor array temperature modulation
# Facebook Live Sellers in Thailand
#
# Multivariate
# Clustering
# Integer
# 7051
# 12
# 2019
# Facebook Live Sellers in Thailand
# Parkinson Dataset with replicated acoustic features
#
# Multivariate
# Classification
#
# 240
# 46
# 2019
# Parkinson Dataset with replicated acoustic features
# Metro Interstate Traffic Volume
#
# Multivariate, Sequential, Time-Series
# Regression
# Integer, Real
# 48204
# 9
# 2019
# Metro Interstate Traffic Volume
# Query Analytics Workloads Dataset
#
# Multivariate
# Regression, Clustering
# Real
# 260000
# 8
# 2019
# Query Analytics Workloads Dataset
# Wave Energy Converters
#
# Multivariate
# Regression
# Real
# 288000
# 49
# 2019
# Wave Energy Converters
# PPG-DaLiA
#
# Multivariate, Time-Series
# Regression
# Real
# 8300000
# 11
# 2019
# PPG-DaLiA
# Alcohol QCM Sensor Dataset
#
# Multivariate
# Classification, Regression, Clustering
# Real
# 125
# 8
# 2019
# Alcohol QCM Sensor Dataset
# Divorce Predictors data set
#
# Multivariate, Univariate
# Classification
# Integer
# 170
# 54
# 2019
# Divorce Predictors data set
# Incident management process enriched event log
#
# Multivariate, Sequential
# Regression, Clustering
# Integer
# 141712
# 36
# 2019
# Incident management process enriched event log
# Opinion Corpus for Lebanese Arabic Reviews (OCLAR)
#
# Text
# Classification
# Integer
# 3916
# 3916
# 2019
# Opinion Corpus for Lebanese Arabic Reviews (OCLAR)
# MEx
#
# Time-Series
# Classification, Clustering
# Real
# 6262
# 710
# 2019
# MEx
# Beijing Multi-Site Air-Quality Data
#
# Multivariate, Time-Series
# Regression
# Integer, Real
# 420768
# 18
# 2019
# Beijing Multi-Site Air-Quality Data
# Online Retail II
#
# Multivariate, Sequential, Time-Series, Text
# Classification, Regression, Clustering
# Integer, Real
# 1067371
# 8
# 2019
# Online Retail II
# Hepatitis C Virus (HCV) for Egyptian patients
#
# Multivariate
# Classification
# Integer, Real
# 1385
# 29
# 2019
# Hepatitis C Virus (HCV) for Egyptian patients
# QSAR fish toxicity
#
# Multivariate
# Regression
# Real
# 908
# 7
# 2019
# QSAR fish toxicity
# QSAR aquatic toxicity
#
# Multivariate
# Regression
# Real
# 546
# 9
# 2019
# QSAR aquatic toxicity
# Human Activity Recognition from Continuous Ambient Sensor Data
#
# Multivariate, Sequential, Time-Series
# Classification
# Integer, Real
# 13956534
# 37
# 2019
# Human Activity Recognition from Continuous Ambient Sensor Data
# WISDM Smartphone and Smartwatch Activity and Biometrics Dataset
#
# Multivariate, Time-Series
# Classification
# Real
# 15630426
# 6
# 2019
# WISDM Smartphone and Smartwatch Activity and Biometrics Dataset
# QSAR oral toxicity
#
# Multivariate
# Classification
#
# 8992
# 1024
# 2019
# QSAR oral toxicity
# QSAR androgen receptor
#
# Multivariate
# Classification
#
# 1687
# 1024
# 2019
# QSAR androgen receptor
# QSAR Bioconcentration classes dataset
#
# Multivariate
# Classification, Regression
#
# 779
# 14
# 2019
# QSAR Bioconcentration classes dataset
# QSAR fish bioconcentration factor (BCF)
#
# Multivariate
# Regression
# Integer, Real
# 1056
# 7
# 2019
# QSAR fish bioconcentration factor (BCF)
# A study of  Asian Religious and Biblical Texts
#
# Multivariate, Text
# Classification, Clustering
# Integer
# 590
# 8265
# 2019
# A study of  Asian Religious and Biblical Texts
# Real-time Election Results: Portugal 2019
#
# Multivariate, Time-Series, Text
# Regression
# Integer, Real
# 21643
# 29
# 2019
# Real-time Election Results: Portugal 2019
# Bias correction of numerical prediction model temperature forecast
#
# Multivariate
# Regression
# Real
# 7750
# 25
# 2020
# Bias correction of numerical prediction model temperature forecast
# Bar Crawl: Detecting Heavy Drinking
#
# Multivariate, Time-Series
# Classification, Regression
# Real
# 14057567
# 3
# 2020
# Bar Crawl: Detecting Heavy Drinking
# Kitsune Network Attack Dataset
#
# Multivariate, Sequential, Time-Series
# Classification, Clustering, Causal-Discovery
# Real
# 27170754
# 115
# 2019
# Kitsune Network Attack Dataset
# Shoulder Implant X-Ray Manufacturer Classification
#
# Multivariate
# Classification
# Real
# 597
# 1
# 2020
# Shoulder Implant X-Ray Manufacturer Classification
# Speaker Accent Recognition
#
# Multivariate
# Classification
# Real
# 329
# 12
# 2020
# Speaker Accent Recognition
# Heart failure clinical records
#
# Multivariate
# Classification, Regression, Clustering
# Integer, Real
# 299
# 13
# 2020
# Heart failure clinical records
# Deepfakes: Medical Image Tamper Detection
#
# Multivariate
# Classification
# Real
# 20000
# 200000
# 2020
# Deepfakes: Medical Image Tamper Detection
# selfBACK
#
# Time-Series
# Classification, Clustering
# Real
# 26136
# 6
# 2020
# selfBACK
# South German Credit
#
# Multivariate
# Classification, Regression, Clustering
# Integer, Real
# 1000
# 21
# 2019
# South German Credit
# Exasens
#
# Multivariate
# Classification, Clustering
# Integer
# 399
# 4
# 2020
# Exasens
# Swarm Behaviour
#
# Multivariate
# Classification
# Real
# 24017
# 2400
# 2020
# Swarm Behaviour
# Crop mapping using fused optical-radar data set
#
# Multivariate, Time-Series
# Classification
# Real
# 325834
# 175
# 2020
# Crop mapping using fused optical-radar data set
# BitcoinHeistRansomwareAddressDataset
#
# Multivariate, Time-Series
# Classification, Clustering
# Integer, Real
# 2916697
# 10
# 2020
# BitcoinHeistRansomwareAddressDataset
# Facebook Large Page-Page Network
#
# Multivariate
# Classification
#
# 22470
# 4714
# 2020
# Facebook Large Page-Page Network
# Amphibians
#
# Multivariate
# Classification
# Integer, Real
# 189
# 23
# 2020
# Amphibians
# Early stage diabetes risk prediction dataset.
#
# Multivariate
# Classification
#
# 520
# 17
# 2020
# Early stage diabetes risk prediction dataset.
# Turkish Spam V01
#
# Text
# Classification
#
# 826
# 2
# 2019
# Turkish Spam V01
# Stock keeping units
#
# Multivariate
# Clustering
# Integer, Real
# 2279
# 9
# 2019
# Stock keeping units
# Demand Forecasting for a store
#
# Multivariate
# Regression
# Integer
# 28764
# 8
# 2019
# Demand Forecasting for a store
# Detect Malware Types
#
# Multivariate, Time-Series, Text
# Classification
#
# 7107
# 280
# 2019
# Detect Malware Types
# Wave Energy Converters
#
# Multivariate
# Regression
# Real
# 288000
# 49
# 2019
# Wave Energy Converters
# Youtube cookery channels viewers comments in Hinglish
#
# Multivariate, Text
# Classification
#
# 9800
# 3
# 2019
# Youtube cookery channels viewers comments in Hinglish
# Pedestrian in Traffic Dataset
#
# Multivariate, Sequential, Time-Series
# Classification, Regression, Causal-Discovery
# Real
# 4760
# 14
# 2019
# Pedestrian in Traffic Dataset
# Cervical Cancer Behavior Risk
#
# Multivariate, Univariate
# Classification, Clustering
# Integer
# 72
# 19
# 2019
# Cervical Cancer Behavior Risk
# Sattriya_Dance_Single_Hand_Gestures Dataset
#
# Multivariate
# Classification
#
# 1450
#
# 2019
# Sattriya_Dance_Single_Hand_Gestures Dataset
# Divorce Predictors data set
#
# Multivariate, Univariate
# Classification
# Integer
# 170
# 54
# 2019
# Divorce Predictors data set
# 3W dataset
#
# Multivariate, Time-Series
# Classification, Clustering
# Integer, Real
# 1984
# 8
# 2019
# 3W dataset
# Malware static and dynamic features VxHeaven and Virus Total
#
# Multivariate
# Classification
# Integer, Real
# 2955
# 1087
# 2019
# Malware static and dynamic features VxHeaven and Virus Total
# Internet Firewall Data
#
# Multivariate
# Classification
#
# 65532
# 12
# 2019
# Internet Firewall Data
# User Profiling and Abusive Language Detection Dataset
#
#
# Classification
#
# 65919
# 3
# 2019
# User Profiling and Abusive Language Detection Dataset
# Estimation of obesity levels based on eating habits and physical condition
#
# Multivariate
# Classification, Regression, Clustering
# Integer
# 2111
# 17
# 2019
# Estimation of obesity levels based on eating habits and physical condition
# Rice (Cammeo and Osmancik)
#
# Multivariate
# Classification
# Real
# 3810
# 8
# 2019
# Rice (Cammeo and Osmancik)
# Vehicle routing and scheduling problems
#
# Multivariate
# Clustering
# Integer, Real
# 18
# 9
# 2019
# Vehicle routing and scheduling problems
# Algerian Forest Fires Dataset
#
# Multivariate
# Classification, Regression
# Real
# 244
# 12
# 2019
# Algerian Forest Fires Dataset
# Breath Metabolomics
#
# Multivariate, Time-Series
# Classification, Clustering
# Real
# 104
# 1656
# 2019
# Breath Metabolomics
# Horton General Hospital
#
# Multivariate, Time-Series
# Causal-Discovery
# Integer
# 139
# 6
# 2019
# Horton General Hospital
# UrbanGB, urban road accidents coordinates labelled by the urban center
#
# Univariate
# Clustering
# Real
# 360177
# 2
# 2019
# UrbanGB, urban road accidents coordinates labelled by the urban center
# Gas Turbine CO and NOx Emission Data Set
#
# Multivariate
# Regression, Clustering
# Real
# 36733
# 11
# 2019
# Gas Turbine CO and NOx Emission Data Set
# Activity recognition using wearable physiological measurements
#
# Multivariate
# Classification
# Real
# 4480
# 533
# 2019
# Activity recognition using wearable physiological measurements
# clickstream data for online shopping
#
# Multivariate, Sequential
# Classification, Regression, Clustering
# Integer, Real
# 165474
# 14
# 2019
# clickstream data for online shopping
# CNNpred: CNN-based stock market prediction using a diverse set of variables
#
# Sequential, Time-Series
# Classification, Regression
# Real
# 1985
# 84
# 2019
# CNNpred: CNN-based stock market prediction using a diverse set of variables
# Apartment for rent classified
#
# Multivariate
# Classification, Regression, Clustering
#
# 10000
# 22
# 2019
# Apartment for rent classified
# : Simulated Data set of Iraqi tourism places
#
# Multivariate
# Classification, Clustering
#
# 232
# 16
# 2020
# : Simulated Data set of Iraqi tourism places
# Nasarian CAD Dataset
#
# Multivariate
# Classification
#
# 150
# 52
# 2020
# Nasarian CAD Dataset
# Monolithic Columns in Troad and Mysia Region
#
# Multivariate
# Classification
# Real
# 11
# 19
# 2020
# Monolithic Columns in Troad and Mysia Region
# Bar Crawl: Detecting Heavy Drinking
#
# Multivariate, Time-Series
# Classification, Regression
# Real
# 14057567
# 3
# 2020
# Bar Crawl: Detecting Heavy Drinking
# Seoul Bike Sharing Demand
#
# Multivariate
# Regression
# Integer, Real
# 8760
# 14
# 2020
# Seoul Bike Sharing Demand
# Person Classification Gait Data
#
# Multivariate
# Classification
# Real
# 48
# 321
# 2020
# Person Classification Gait Data
# Shill Bidding Dataset
#
# Multivariate
# Classification, Clustering
#
# 6321
# 13
# 2020
# Shill Bidding Dataset
# Iranian Churn Dataset
#
# Multivariate
# Classification, Regression
# Integer
# 3150
# 13
# 2020
# Iranian Churn Dataset
# Unmanned Aerial Vehicle (UAV) Intrusion Detection
#
# Multivariate
# Classification
# Real
# 17256
# 55
# 2020
# Unmanned Aerial Vehicle (UAV) Intrusion Detection
# Bone marrow transplant: children
#
# Multivariate
# Classification, Regression
# Integer, Real
# 187
# 39
# 2020
# Bone marrow transplant: children
# Exasens
#
# Multivariate
# Classification, Clustering
# Integer
# 399
# 4
# 2020
# Exasens
# COVID-19 Surveillance
#
# Multivariate
# Classification
#
# 14
# 7
# 2020
# COVID-19 Surveillance
# Refractive errors
#
# Multivariate
# Classification
# Integer
# 467
# 79
# 2020
# Refractive errors
# Shoulder Implant X-Ray Manufacturer Classification
#
# Multivariate
# Classification
# Real
# 597
# 1
# 2020
# Shoulder Implant X-Ray Manufacturer Classification
# CLINC150
#
# Text
# Classification
#
# 23700
#
# 2020
# CLINC150
# HCV data
#
# Multivariate
# Classification, Clustering
# Integer, Real
# 615
# 14
# 2020
# HCV data
# Taiwanese Bankruptcy Prediction
#
# Multivariate
# Classification
# Integer
# 6819
# 96
# 2020
# Taiwanese Bankruptcy Prediction
# South German Credit (UPDATE)
#
# Multivariate
# Classification, Regression, Clustering
# Integer, Real
# 1000
# 21
# 2020
# South German Credit (UPDATE)
# IIWA14-R820-Gazebo-Dataset-10Trajectories
#
#
# Regression
# Integer
#
#
# 2020
# IIWA14-R820-Gazebo-Dataset-10Trajectories
# Guitar Chords finger positions
#
# Text
# Classification
#
# 2633
# 5
# 2020
# Guitar Chords finger positions
# Russian Corpus of Biographical Texts
#
# Text
# Classification
#
# 200
# 2
# 2020
# Russian Corpus of Biographical Texts
# Codon usage
#
# Multivariate
# Classification, Clustering
#
# 13028
# 69
# 2020
# Codon usage
# Intelligent Media Accelerometer and Gyroscope (IM-AccGyro) Dataset
#
# Time-Series
# Classification
# Real
# 800
# 9
# 2020
# Intelligent Media Accelerometer and Gyroscope (IM-AccGyro) Dataset
# Myocardial infarction complications
#
# Multivariate
# Classification
# Real
# 1700
# 124
# 2020
# Myocardial infarction complications
# Hungarian Chickenpox Cases
#
# Time-Series
# Regression
# Real
# 521
# 20
# 2021
# Hungarian Chickenpox Cases
# Simulated data for survival modelling
#
# Multivariate, Time-Series
# Regression
# Integer, Real
# 120000
# 25
# 2018
# Simulated data for survival modelling
# Student Performance on an entrance examination
#
# Multivariate
# Classification
#
# 666
# 11
# 2018
# Student Performance on an entrance examination
# Chemical Composition of Ceramic Samples
#
# Multivariate
# Classification, Clustering
# Real
# 88
# 19
# 2019
# Chemical Composition of Ceramic Samples
# Labeled Text Forum Threads Dataset
#
# Text
# Classification
# Integer
# 200
# 9
# 2019
# Labeled Text Forum Threads Dataset
# Stock keeping units
#
# Multivariate
# Clustering
# Integer, Real
# 2279
# 9
# 2019
# Stock keeping units
# BLE RSSI dataset for Indoor localization
#
# Sequential, Time-Series
# Classification
# Integer
# 23570
# 5
# 2019
# BLE RSSI dataset for Indoor localization
# Basketball dataset
#
# Time-Series
# Classification
# Integer
# 10000
# 7
# 2019
# Basketball dataset
# GitHub MUSAE
#
# Multivariate
# Classification
#
# 37700
# 4006
# 2019
# GitHub MUSAE
# Anticancer peptides
#
# Sequential
# Classification
#
# 1850
# 2
# 2019
# Anticancer peptides
# Monolithic Columns in Troad and Mysia Region
#
# Multivariate
# Classification
# Real
# 11
# 19
# 2020
# Monolithic Columns in Troad and Mysia Region
# Gender by Name
#
# Text
# Classification, Clustering
#
# 147270
# 4
# 2020
# Gender by Name
# Iranian Churn Dataset
#
# Multivariate
# Classification, Regression
# Integer
# 3150
# 13
# 2020
# Iranian Churn Dataset
# Unmanned Aerial Vehicle (UAV) Intrusion Detection
#
# Multivariate
# Classification
# Real
# 17256
# 55
# 2020
# Unmanned Aerial Vehicle (UAV) Intrusion Detection
# Shoulder Implant Manufacture Classification
#
# Multivariate
# Classification
#
# 597
# 1
# 2020
# Shoulder Implant Manufacture Classification
# LastFM Asia Social Network
#
# Multivariate
# Classification
#
# 7624
# 7842
# 2020
# LastFM Asia Social Network
# Wheat kernels
#
# Multivariate
# Classification
# Real
# 314
# 15
# 2020
# Wheat kernels
# Productivity Prediction of Garment Employees
#
# Multivariate, Time-Series
# Classification, Regression
# Integer, Real
# 1197
# 15
# 2020
# Productivity Prediction of Garment Employees
# Multi-view Brain Networks
#
# Multivariate
# Classification, Clustering
# Integer
# 70
# 70
# 2020
# Multi-view Brain Networks
# LastFM Asia Social Network
#
# Multivariate
# Classification
#
# 7624
# 7842
# 2020
# LastFM Asia Social Network
# Wisesight Sentiment Corpus
#
# Multivariate, Text
# Classification
#
# 26737
# 4
# 2020
# Wisesight Sentiment Corpus
# AI4I 2020 Predictive Maintenance Dataset
#
# Multivariate, Time-Series
# Classification, Regression, Causal-Discovery
# Real
# 10000
# 14
# 2020
# AI4I 2020 Predictive Maintenance Dataset
# Dry Bean Dataset
#
# Multivariate
# Classification
# Integer, Real
# 13611
# 17
# 2020
# Dry Bean Dataset
# in-vehicle coupon recommendation
#
# Multivariate
# Classification
#
# 12684
# 23
# 2020
# in-vehicle coupon recommendation
# Gait Classification
#
# Multivariate
# Classification
# Real
# 48
# 321
# 2020
# Gait Classification
# Wikipedia Math Essentials
#
# Time-Series
# Regression
# Real
# 731
# 1068
# 2021
# Wikipedia Math Essentials
# Wikipedia Math Essentials
#
# Time-Series
# Regression
# Real
# 731
# 1068
# 2021
# Wikipedia Math Essentials
# Synchronous Machine Data Set
#
# Multivariate
# Regression
# Real
# 557
# 5
# 2021
# Synchronous Machine Data Set
